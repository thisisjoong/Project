# %%
import requests



url = "https://api.pubg.com/shards/steam/players?filter[playerNames]=Berynie"
api_key = '####'

header = {
  "Authorization": api_key,
  "Accept": "application/vnd.api+json"
}

r = requests.get(url, headers=header)
read_json = r.json()
print(read_json)

#my acoount : account.840d28236c3b4bd2aba9b1e2baa92ef0
# Out:
# {'data': [{'type': 'player', 'id': 'account.840d28236c3b4bd2aba9b1e2baa92ef0', 'attributes': {'stats': None, 'titleId': 'pubg', 'shardId': 'steam', 'patchVersion': '', 'name': 'Berynie'}, 'relationships': {'assets': {'data': []}, 'matches': {'data': [{'type': 'match', 'id': '3d88e9f0-b06d-471d-a69e-941aae5a38f7'}, {'type': 'match', 'id': '824cbfe1-754a-41cc-bd0b-ef91df625f62'}, {'type': 'match', 'id': '6000851a-8769-4ed5-8890-c1b710e25ee9'}, {'type': 'match', 'id': '0aae7fd8-6b76-4cbf-82ba-1743a62ae73e'}, {'type': 'match', 'id': '89c726a4-7cb4-495c-9351-8f1befe0d8ca'}, {'type': 'match', 'id': '1055d4c3-25cd-484e-a0db-7c20f6295f4f'}, {'type': 'match', 'id': '31cd63f4-b5a7-4659-aca9-1686feec6e50'}, {'type': 'match', 'id': '91587e1b-da4a-4f1f-98fc-f72e330e8a96'}, {'type': 'match', 'id': '3d8b0e99-2d97-46b1-8da1-8bf6b5fef5a3'}, {'type': 'match', 'id': 'c7dd13b7-2094-4ae6-a4b9-4eb2ff40e38b'}, {'type': 'match', 'id': '3fb42ea6-0eab-49e3-ace9-df7788d655b5'}, {'type': 'match', 'id': '72682d36-cd60-4179-85fe-20cb3418ff9b'}, {'type': 'match', 'id': 'e21152b2-14d0-47c2-af43-1018ceb02169'}, {'type': 'match', 'id': 'ff2c815b-a239-4d5b-a51b-eb5bef16fd46'}, {'type': 'match', 'id': 'e566ea62-7162-47be-9e3c-1ecfcd2b88ae'}, {'type': 'match', 'id': '767de318-35df-41ed-ba48-6c63104795bd'}, {'type': 'match', 'id': '6c463e67-584e-47b1-bdd9-50caecd0ab82'}, {'type': 'match', 'id': '3a3d523c-d43d-4c16-9238-65adcbefc8fa'}, {'type': 'match', 'id': '9802c765-c421-40eb-b869-bbf410a2049a'}, {'type': 'match', 'id': '106fb5f1-13e9-4377-8dc9-6dc411bfc601'}, {'type': 'match', 'id': 'df66e70d-9a85-4de2-ba92-993ee0cb99c8'}, {'type': 'match', 'id': 'a8a789c1-c8bb-4cb8-a086-5be3d9b23358'}, {'type': 'match', 'id': 'f7240436-203a-48aa-ad87-6e6f7fef7ead'}, {'type': 'match', 'id': '881260b9-1e25-4ff6-9b40-95c17be7acb3'}]}}, 'links': {'self': 'https://api.pubg.com/shards/steam/players/account.840d28236c3b4bd2aba9b1e2baa92ef0', 'schema': ''}}], 'links': {'self': 'https://api.pubg.com/shards/steam/players?filter[playerNames]=Berynie'}, 'meta': {}}

# %%
matchId = read_json['data'][0]['relationships']['matches']['data']
matchId
# Out:
# [{'id': '3d88e9f0-b06d-471d-a69e-941aae5a38f7', 'type': 'match'},
#  {'id': '824cbfe1-754a-41cc-bd0b-ef91df625f62', 'type': 'match'},
#  {'id': '6000851a-8769-4ed5-8890-c1b710e25ee9', 'type': 'match'},
#  {'id': '0aae7fd8-6b76-4cbf-82ba-1743a62ae73e', 'type': 'match'},
#  {'id': '89c726a4-7cb4-495c-9351-8f1befe0d8ca', 'type': 'match'},
#  {'id': '1055d4c3-25cd-484e-a0db-7c20f6295f4f', 'type': 'match'},
#  {'id': '31cd63f4-b5a7-4659-aca9-1686feec6e50', 'type': 'match'},
#  {'id': '91587e1b-da4a-4f1f-98fc-f72e330e8a96', 'type': 'match'},
#  {'id': '3d8b0e99-2d97-46b1-8da1-8bf6b5fef5a3', 'type': 'match'},
#  {'id': 'c7dd13b7-2094-4ae6-a4b9-4eb2ff40e38b', 'type': 'match'},
#  {'id': '3fb42ea6-0eab-49e3-ace9-df7788d655b5', 'type': 'match'},
#  {'id': '72682d36-cd60-4179-85fe-20cb3418ff9b', 'type': 'match'},
#  {'id': 'e21152b2-14d0-47c2-af43-1018ceb02169', 'type': 'match'},
#  {'id': 'ff2c815b-a239-4d5b-a51b-eb5bef16fd46', 'type': 'match'},
#  {'id': 'e566ea62-7162-47be-9e3c-1ecfcd2b88ae', 'type': 'match'},
#  {'id': '767de318-35df-41ed-ba48-6c63104795bd', 'type': 'match'},
#  {'id': '6c463e67-584e-47b1-bdd9-50caecd0ab82', 'type': 'match'},
#  {'id': '3a3d523c-d43d-4c16-9238-65adcbefc8fa', 'type': 'match'},
#  {'id': '9802c765-c421-40eb-b869-bbf410a2049a', 'type': 'match'},
#  {'id': '106fb5f1-13e9-4377-8dc9-6dc411bfc601', 'type': 'match'},
#  {'id': 'df66e70d-9a85-4de2-ba92-993ee0cb99c8', 'type': 'match'},
#  {'id': 'a8a789c1-c8bb-4cb8-a086-5be3d9b23358', 'type': 'match'},
#  {'id': 'f7240436-203a-48aa-ad87-6e6f7fef7ead', 'type': 'match'},
#  {'id': '881260b9-1e25-4ff6-9b40-95c17be7acb3', 'type': 'match'}]

# %%
matchId_li = []

for i in range(0,len(matchId)):
  matchId_li.append(matchId[i]['id'])

# %%
import requests
import pandas as pd
import pprint

url = "https://api.pubg.com/shards/steam/matches/"
api_key = '#####'

header = {
  "Authorization": api_key,
  "Accept": "application/vnd.api+json"
}

r = requests.get(url+ matchId_li[0], headers=header)
first_match = r.json()
#print(read_json)

# %%
first_match_data = first_match['included']  #각 플레이어 관한 데이터가 'attributes'안에 있음
first_match_info = first_match['data']  #해당게임 전반적인 데이터

# %%
attribute_li= []

for i in range (len(first_match_data)):
  attribute_li.append(first_match_data[i]['attributes'])

# %%
attribute_li
# Out:
# [{'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 0,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 57,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'YECUD',
#    'playerId': 'account.8246582a51b841c69cd44a9d73ea4b5f',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 91,
#    'vehicleDestroys': 0,
#    'walkDistance': 102.86283,
#    'weaponsAcquired': 0,
#    'winPlace': 28}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 0,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 61,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'gkwns5919',
#    'playerId': 'account.6d4fee17395c44ce979da6e35c230af3',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 81,
#    'vehicleDestroys': 0,
#    'walkDistance': 3.868862,
#    'weaponsAcquired': 0,
#    'winPlace': 32}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 2,
#    'damageDealt': 0,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 4,
#    'killPlace': 31,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'Berynie',
#    'playerId': 'account.840d28236c3b4bd2aba9b1e2baa92ef0',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 703,
#    'vehicleDestroys': 0,
#    'walkDistance': 1109.0815,
#    'weaponsAcquired': 5,
#    'winPlace': 5}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 1,
#    'damageDealt': 0,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 1,
#    'killPlace': 45,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'DEAD_ART1STS',
#    'playerId': 'account.90bca275c8594afdac0120f0da7e8b19',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 355,
#    'vehicleDestroys': 0,
#    'walkDistance': 561.13965,
#    'weaponsAcquired': 2,
#    'winPlace': 21}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 1,
#    'assists': 0,
#    'boosts': 5,
#    'damageDealt': 176.06929,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 1,
#    'killPlace': 16,
#    'killStreaks': 1,
#    'kills': 1,
#    'longestKill': 96.78275,
#    'name': 'jaehomaster',
#    'playerId': 'account.1e4d4579333a47eb97cbfd2f11c46938',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 1015,
#    'vehicleDestroys': 0,
#    'walkDistance': 1905.3821,
#    'weaponsAcquired': 3,
#    'winPlace': 4}},
#  {'shardId': 'steam', 'stats': {'rank': 1, 'teamId': 26}, 'won': 'true'},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 0,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 49,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'buhungtek',
#    'playerId': 'account.2e4a47c86f2a49809d784680f82d2b3c',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 139,
#    'vehicleDestroys': 0,
#    'walkDistance': 195.92365,
#    'weaponsAcquired': 3,
#    'winPlace': 23}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 4,
#    'damageDealt': 100,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 1,
#    'killPlace': 20,
#    'killStreaks': 1,
#    'kills': 1,
#    'longestKill': 12.231489,
#    'name': 'POCHA_JIN',
#    'playerId': 'account.47709a94c36f4f9b9cc97208bb90e996',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 758,
#    'vehicleDestroys': 0,
#    'walkDistance': 1577.6672,
#    'weaponsAcquired': 3,
#    'winPlace': 12}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 2,
#    'damageDealt': 0,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 39,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'SaeRom-',
#    'playerId': 'account.45b9839baf5a4c6b9580e1424c5ef78f',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 482,
#    'vehicleDestroys': 0,
#    'walkDistance': 639.04767,
#    'weaponsAcquired': 4,
#    'winPlace': 16}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 1,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 154.56871,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 4,
#    'killPlace': 50,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'M1RA',
#    'playerId': 'account.01dadccfac33462180ecb8479122efee',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 225,
#    'vehicleDestroys': 0,
#    'walkDistance': 315.92368,
#    'weaponsAcquired': 2,
#    'winPlace': 24}},
#  {'shardId': 'steam', 'stats': {'rank': 4, 'teamId': 31}, 'won': 'false'},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 0,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 41,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'hiroponti',
#    'playerId': 'account.f7716520b48242059bae610b8b59acf7',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 406,
#    'vehicleDestroys': 0,
#    'walkDistance': 686.283,
#    'weaponsAcquired': 4,
#    'winPlace': 17}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 0,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 60,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'jyjy0_401',
#    'playerId': 'ai.314',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 309,
#    'vehicleDestroys': 0,
#    'walkDistance': 146.22256,
#    'weaponsAcquired': 0,
#    'winPlace': 31}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 21.6,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 54,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'SOYA005',
#    'playerId': 'account.b237730d253e490abe9c6edb438368da',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 163,
#    'vehicleDestroys': 0,
#    'walkDistance': 143.65797,
#    'weaponsAcquired': 8,
#    'winPlace': 26}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 1,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 100,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 53,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'bigmackorea',
#    'playerId': 'account.9c2b69d2881143dc871ae486a93e623b',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 186,
#    'vehicleDestroys': 0,
#    'walkDistance': 104.459015,
#    'weaponsAcquired': 4,
#    'winPlace': 26}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 0,
#    'deathType': 'byzone',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 63,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'Cupid1010',
#    'playerId': 'account.3b15698a19a74a94852ac83809931ec2',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 404,
#    'vehicleDestroys': 0,
#    'walkDistance': 0,
#    'weaponsAcquired': 0,
#    'winPlace': 33}},
#  {'shardId': 'steam', 'stats': {'rank': 7, 'teamId': 9}, 'won': 'false'},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 1,
#    'assists': 1,
#    'boosts': 1,
#    'damageDealt': 292.0309,
#    'deathType': 'byplayer',
#    'headshotKills': 1,
#    'heals': 6,
#    'killPlace': 13,
#    'killStreaks': 1,
#    'kills': 2,
#    'longestKill': 165.68877,
#    'name': 'Havoc-Tina',
#    'playerId': 'account.f1290ebdb65d4707a51b607244f0b922',
#    'revives': 1,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 550,
#    'vehicleDestroys': 0,
#    'walkDistance': 921.7049,
#    'weaponsAcquired': 5,
#    'winPlace': 14}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 2,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 275,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 15,
#    'killStreaks': 2,
#    'kills': 2,
#    'longestKill': 6.2836213,
#    'name': 'rlaejrfuf1',
#    'playerId': 'account.c698b37eafff4f59aadcbaa8eed35ada',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 250,
#    'vehicleDestroys': 0,
#    'walkDistance': 296.6317,
#    'weaponsAcquired': 3,
#    'winPlace': 23}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 1,
#    'assists': 1,
#    'boosts': 4,
#    'damageDealt': 272.34058,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 10,
#    'killPlace': 10,
#    'killStreaks': 1,
#    'kills': 2,
#    'longestKill': 123.36455,
#    'name': 'DontHide',
#    'playerId': 'account.1023a5d9426b4f638eebdef01b54fdb0',
#    'revives': 2,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 817,
#    'vehicleDestroys': 0,
#    'walkDistance': 1839.947,
#    'weaponsAcquired': 3,
#    'winPlace': 9}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 1,
#    'assists': 1,
#    'boosts': 4,
#    'damageDealt': 296.9257,
#    'deathType': 'byplayer',
#    'headshotKills': 1,
#    'heals': 0,
#    'killPlace': 6,
#    'killStreaks': 1,
#    'kills': 3,
#    'longestKill': 8.165401,
#    'name': 'Ricochet_-',
#    'playerId': 'account.ba72f0c09beb43f191aa95067b407d02',
#    'revives': 1,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 769,
#    'vehicleDestroys': 0,
#    'walkDistance': 1501.2141,
#    'weaponsAcquired': 8,
#    'winPlace': 10}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 1,
#    'assists': 2,
#    'boosts': 5,
#    'damageDealt': 263.1525,
#    'deathType': 'byzone',
#    'headshotKills': 0,
#    'heals': 4,
#    'killPlace': 11,
#    'killStreaks': 1,
#    'kills': 2,
#    'longestKill': 45.14415,
#    'name': 'Im-pervert',
#    'playerId': 'account.1e73540ef30a4a4291b4e13fcc791b90',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 769,
#    'vehicleDestroys': 0,
#    'walkDistance': 1478.067,
#    'weaponsAcquired': 6,
#    'winPlace': 10}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 1,
#    'damageDealt': 43.099777,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 1,
#    'killPlace': 34,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'enlteka4',
#    'playerId': 'account.5913bfde3fb348f09252259eba14204c',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 886,
#    'vehicleDestroys': 0,
#    'walkDistance': 669.4114,
#    'weaponsAcquired': 5,
#    'winPlace': 8}},
#  {'shardId': 'steam', 'stats': {'rank': 15, 'teamId': 5}, 'won': 'false'},
#  {'shardId': 'steam', 'stats': {'rank': 12, 'teamId': 14}, 'won': 'false'},
#  {'shardId': 'steam', 'stats': {'rank': 26, 'teamId': 29}, 'won': 'false'},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 3,
#    'assists': 0,
#    'boosts': 3,
#    'damageDealt': 302.78198,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 1,
#    'killPlace': 4,
#    'killStreaks': 1,
#    'kills': 4,
#    'longestKill': 171.04797,
#    'name': 'Feb1oth',
#    'playerId': 'account.680fdb6111624967a71b94796f46f3f9',
#    'revives': 1,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 915,
#    'vehicleDestroys': 0,
#    'walkDistance': 2087.3364,
#    'weaponsAcquired': 5,
#    'winPlace': 6}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 0,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 56,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'qkdxksSOL',
#    'playerId': 'account.1757b016835b4c0babb77dab0749e260',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 88,
#    'vehicleDestroys': 0,
#    'walkDistance': 64.85366,
#    'weaponsAcquired': 1,
#    'winPlace': 27}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 2,
#    'boosts': 6,
#    'damageDealt': 345.53775,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 8,
#    'killPlace': 8,
#    'killStreaks': 1,
#    'kills': 2,
#    'longestKill': 73.5273,
#    'name': 'DM-MINO',
#    'playerId': 'account.01b726427f1747beabed1aa66aa6afb3',
#    'revives': 1,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 1118,
#    'vehicleDestroys': 0,
#    'walkDistance': 1643.371,
#    'weaponsAcquired': 2,
#    'winPlace': 3}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 3,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 620.49756,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 1,
#    'killPlace': 7,
#    'killStreaks': 1,
#    'kills': 3,
#    'longestKill': 48.187477,
#    'name': 'dbswnstj99140909',
#    'playerId': 'account.9a34780781ca49c4854c9e62426dfcbd',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 439,
#    'vehicleDestroys': 0,
#    'walkDistance': 716.636,
#    'weaponsAcquired': 3,
#    'winPlace': 18}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 1,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 100,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 24,
#    'killStreaks': 1,
#    'kills': 1,
#    'longestKill': 59.29475,
#    'name': 'show3459a',
#    'playerId': 'account.b6a45e76357f4f70b72be56f4efa44ee',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 195,
#    'vehicleDestroys': 0,
#    'walkDistance': 257.85812,
#    'weaponsAcquired': 2,
#    'winPlace': 25}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 2,
#    'assists': 0,
#    'boosts': 2,
#    'damageDealt': 245,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 1,
#    'killPlace': 9,
#    'killStreaks': 2,
#    'kills': 2,
#    'longestKill': 62.747692,
#    'name': 'kimdm1203',
#    'playerId': 'account.45252566768542798f77a35e3f565aa9',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 448,
#    'vehicleDestroys': 0,
#    'walkDistance': 772.57135,
#    'weaponsAcquired': 4,
#    'winPlace': 8}},
#  {'shardId': 'steam', 'stats': {'rank': 5, 'teamId': 4}, 'won': 'false'},
#  {'shardId': 'steam', 'stats': {'rank': 21, 'teamId': 2}, 'won': 'false'},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 6,
#    'damageDealt': 212.73146,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 7,
#    'killPlace': 19,
#    'killStreaks': 1,
#    'kills': 1,
#    'longestKill': 6.0738215,
#    'name': 'kibummmmm',
#    'playerId': 'account.925d9c7efa274a06a046db492699d8ce',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 894,
#    'vehicleDestroys': 0,
#    'walkDistance': 1943.0217,
#    'weaponsAcquired': 5,
#    'winPlace': 7}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 0,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 65,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'GOLDMAN_-_',
#    'playerId': 'account.1ded0da5993e4ce69b7234c81a692610',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 62,
#    'vehicleDestroys': 0,
#    'walkDistance': 6.2386436,
#    'weaponsAcquired': 1,
#    'winPlace': 33}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 0,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 55,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'DODO_317',
#    'playerId': 'account.7d399199798841faaf5d0ff1253c3372',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 178,
#    'vehicleDestroys': 0,
#    'walkDistance': 357.93988,
#    'weaponsAcquired': 4,
#    'winPlace': 27}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 1,
#    'damageDealt': 49.17311,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 1,
#    'killPlace': 48,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'da_kyeong2',
#    'playerId': 'account.dff3e124d71a42ecbbf12635ab40908b',
#    'revives': 1,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 261,
#    'vehicleDestroys': 0,
#    'walkDistance': 161.20569,
#    'weaponsAcquired': 3,
#    'winPlace': 22}},
#  {'shardId': 'steam', 'stats': {'rank': 23, 'teamId': 28}, 'won': 'false'},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 1,
#    'assists': 0,
#    'boosts': 3,
#    'damageDealt': 31.644997,
#    'deathType': 'byplayer',
#    'headshotKills': 1,
#    'heals': 2,
#    'killPlace': 21,
#    'killStreaks': 1,
#    'kills': 1,
#    'longestKill': 6.6332035,
#    'name': 'Gang_53',
#    'playerId': 'account.787eaa6fea744066830e3d18c8ee5596',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 525,
#    'vehicleDestroys': 0,
#    'walkDistance': 888.84564,
#    'weaponsAcquired': 4,
#    'winPlace': 14}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 1,
#    'assists': 0,
#    'boosts': 4,
#    'damageDealt': 318.14984,
#    'deathType': 'alive',
#    'headshotKills': 0,
#    'heals': 1,
#    'killPlace': 29,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'Acechoi_95',
#    'playerId': 'account.2ac1849a594247f7b73425fb50323c1f',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 669,
#    'vehicleDestroys': 0,
#    'walkDistance': 1352.6333,
#    'weaponsAcquired': 3,
#    'winPlace': 1}},
#  {'shardId': 'steam', 'stats': {'rank': 29, 'teamId': 15}, 'won': 'false'},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 3,
#    'assists': 0,
#    'boosts': 5,
#    'damageDealt': 603.3496,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 4,
#    'killPlace': 5,
#    'killStreaks': 2,
#    'kills': 4,
#    'longestKill': 219.50647,
#    'name': 'SSK666',
#    'playerId': 'account.4bb915f18f494d2099320de1a8d60076',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 817,
#    'vehicleDestroys': 0,
#    'walkDistance': 1584.415,
#    'weaponsAcquired': 6,
#    'winPlace': 9}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 0,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 59,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'GeneralGon',
#    'playerId': 'account.8685491b885c444993120d9985bd48ef',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 113,
#    'vehicleDestroys': 0,
#    'walkDistance': 21.913591,
#    'weaponsAcquired': 0,
#    'winPlace': 29}},
#  {'shardId': 'steam', 'stats': {'rank': 9, 'teamId': 11}, 'won': 'false'},
#  {'shardId': 'steam', 'stats': {'rank': 30, 'teamId': 13}, 'won': 'false'},
#  {'shardId': 'steam', 'stats': {'rank': 17, 'teamId': 16}, 'won': 'false'},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 0,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 38,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'ga_you',
#    'playerId': 'account.de6ac5b472ad4ca3a3468a98bd76d9c5',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 229,
#    'vehicleDestroys': 0,
#    'walkDistance': 71.092674,
#    'weaponsAcquired': 4,
#    'winPlace': 15}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 1,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 176.01839,
#    'deathType': 'byplayer',
#    'headshotKills': 1,
#    'heals': 0,
#    'killPlace': 25,
#    'killStreaks': 1,
#    'kills': 1,
#    'longestKill': 3.3003168,
#    'name': 'HYUNseo236',
#    'playerId': 'account.ac195e4fbb8e41988741ba672b53dafd',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 123,
#    'vehicleDestroys': 0,
#    'walkDistance': 88.85303,
#    'weaponsAcquired': 1,
#    'winPlace': 28}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 0,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 52,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'show3459',
#    'playerId': 'account.5e4a3cad177a4006ae6938ab8fb2e12b',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 195,
#    'vehicleDestroys': 0,
#    'walkDistance': 326.2434,
#    'weaponsAcquired': 2,
#    'winPlace': 25}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 1,
#    'assists': 0,
#    'boosts': 4,
#    'damageDealt': 371.52957,
#    'deathType': 'byplayer',
#    'headshotKills': 1,
#    'heals': 4,
#    'killPlace': 12,
#    'killStreaks': 1,
#    'kills': 2,
#    'longestKill': 43.77705,
#    'name': 'Named_Seodaemun',
#    'playerId': 'account.dcba077f18c840b28d8433780fd16449',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 769,
#    'vehicleDestroys': 0,
#    'walkDistance': 1573.6025,
#    'weaponsAcquired': 7,
#    'winPlace': 11}},
#  {'shardId': 'steam', 'stats': {'rank': 10, 'teamId': 30}, 'won': 'false'},
#  {'shardId': 'steam', 'stats': {'rank': 31, 'teamId': 201}, 'won': 'false'},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 0,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 58,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': '18--ak',
#    'playerId': 'account.72a06df13b1c49eba0de54ec5a2e7a7d',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 121,
#    'vehicleDestroys': 0,
#    'walkDistance': 60.95614,
#    'weaponsAcquired': 1,
#    'winPlace': 29}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 1,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 296.35,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 26,
#    'killStreaks': 1,
#    'kills': 1,
#    'longestKill': 25.522556,
#    'name': '2changmin2',
#    'playerId': 'account.6f60ced46a3746f8ab4f44314b1cc208',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 101,
#    'vehicleDestroys': 0,
#    'walkDistance': 43.66642,
#    'weaponsAcquired': 2,
#    'winPlace': 30}},
#  {'shardId': 'steam', 'stats': {'rank': 6, 'teamId': 7}, 'won': 'false'},
#  {'shardId': 'steam', 'stats': {'rank': 27, 'teamId': 10}, 'won': 'false'},
#  {'shardId': 'steam', 'stats': {'rank': 32, 'teamId': 23}, 'won': 'false'},
#  {'shardId': 'steam', 'stats': {'rank': 24, 'teamId': 12}, 'won': 'false'},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 2,
#    'assists': 0,
#    'boosts': 6,
#    'damageDealt': 364.6321,
#    'deathType': 'byplayer',
#    'headshotKills': 1,
#    'heals': 5,
#    'killPlace': 3,
#    'killStreaks': 1,
#    'kills': 4,
#    'longestKill': 101.68948,
#    'name': 'Brian1126',
#    'playerId': 'account.c6ee0b6256ff43e2822083103e675fd7',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 1181,
#    'vehicleDestroys': 0,
#    'walkDistance': 2176.489,
#    'weaponsAcquired': 6,
#    'winPlace': 2}},
#  {'shardId': 'steam', 'stats': {'rank': 16, 'teamId': 24}, 'won': 'false'},
#  {'shardId': 'steam', 'stats': {'rank': 18, 'teamId': 20}, 'won': 'false'},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 1,
#    'boosts': 2,
#    'damageDealt': 145.67487,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 1,
#    'killPlace': 32,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'D-Generation_X29',
#    'playerId': 'account.1a7c4fc930aa47a28adb43ad7c1d2616',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 915,
#    'vehicleDestroys': 0,
#    'walkDistance': 2321.4983,
#    'weaponsAcquired': 6,
#    'winPlace': 6}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 25.199999,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 43,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'Pan_Ruchao',
#    'playerId': 'ai.312',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 628,
#    'vehicleDestroys': 0,
#    'walkDistance': 643.88873,
#    'weaponsAcquired': 0,
#    'winPlace': 19}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 1,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 99.99999,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 27,
#    'killStreaks': 1,
#    'kills': 1,
#    'longestKill': 18.29789,
#    'name': 'welcomejun',
#    'playerId': 'account.fdad253e33554c3d8093b0ae0dcd6420',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 101,
#    'vehicleDestroys': 0,
#    'walkDistance': 41.406105,
#    'weaponsAcquired': 3,
#    'winPlace': 30}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 4,
#    'assists': 0,
#    'boosts': 9,
#    'damageDealt': 820.31744,
#    'deathType': 'alive',
#    'headshotKills': 0,
#    'heals': 7,
#    'killPlace': 1,
#    'killStreaks': 2,
#    'kills': 8,
#    'longestKill': 185.42772,
#    'name': '9166signalman',
#    'playerId': 'account.bacb8c24fb774909877468bb76fd9edd',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 1184,
#    'vehicleDestroys': 0,
#    'walkDistance': 2040.2416,
#    'weaponsAcquired': 4,
#    'winPlace': 1}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 1,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 313.64877,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 14,
#    'killStreaks': 2,
#    'kills': 2,
#    'longestKill': 43.885094,
#    'name': 'dntjqWkd',
#    'playerId': 'account.751ba279673e420086de4015014ecd19',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 261,
#    'vehicleDestroys': 0,
#    'walkDistance': 147.58804,
#    'weaponsAcquired': 2,
#    'winPlace': 22}},
#  {'shardId': 'steam', 'stats': {'rank': 2, 'teamId': 1}, 'won': 'false'},
#  {'shardId': 'steam', 'stats': {'rank': 3, 'teamId': 22}, 'won': 'false'},
#  {'shardId': 'steam', 'stats': {'rank': 25, 'teamId': 27}, 'won': 'false'},
#  {'shardId': 'steam', 'stats': {'rank': 11, 'teamId': 21}, 'won': 'false'},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 3,
#    'damageDealt': 15.519489,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 1,
#    'killPlace': 37,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'DHGFJY',
#    'playerId': 'account.9f31d46410b14ddbbe61bb4db366de9b',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 17.403526,
#    'teamKills': 0,
#    'timeSurvived': 669,
#    'vehicleDestroys': 0,
#    'walkDistance': 1205.48,
#    'weaponsAcquired': 8,
#    'winPlace': 13}},
#  {'shardId': 'steam', 'stats': {'rank': 14, 'teamId': 19}, 'won': 'false'},
#  {'shardId': 'steam', 'stats': {'rank': 19, 'teamId': 200}, 'won': 'false'},
#  {'URL': 'https://telemetry-cdn.pubg.com/bluehole-pubg/steam/2021/09/03/15/37/cf835326-0ccc-11ec-bc41-6eb9a4f2a6c1-telemetry.json',
#   'createdAt': '2021-09-03T15:37:13Z',
#   'description': '',
#   'name': 'telemetry'},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 2,
#    'damageDealt': 0,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 33,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'Baekyongwoo-',
#    'playerId': 'account.cd7a9ef357794aa8858069a444a9cc23',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 445,
#    'vehicleDestroys': 0,
#    'walkDistance': 920.08374,
#    'weaponsAcquired': 2,
#    'winPlace': 7}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 3,
#    'damageDealt': 71.6074,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 36,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'LG_gram',
#    'playerId': 'account.4b082a671de54c5eb5bfea4a1e03927d',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 687,
#    'vehicleDestroys': 0,
#    'walkDistance': 1251.1528,
#    'weaponsAcquired': 4,
#    'winPlace': 12}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 0,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 62,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'ImShady_',
#    'playerId': 'account.cabeace16f184c10919b205b647c9651',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 81,
#    'vehicleDestroys': 0,
#    'walkDistance': 88.01981,
#    'weaponsAcquired': 0,
#    'winPlace': 32}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 105.42233,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 47,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'Finalofangel',
#    'playerId': 'account.c092845f6e2d432382e6d0eabcc9865e',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 284,
#    'vehicleDestroys': 0,
#    'walkDistance': 391.86804,
#    'weaponsAcquired': 2,
#    'winPlace': 21}},
#  {'shardId': 'steam', 'stats': {'rank': 22, 'teamId': 3}, 'won': 'false'},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 1,
#    'assists': 0,
#    'boosts': 2,
#    'damageDealt': 54.39988,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 22,
#    'killStreaks': 1,
#    'kills': 1,
#    'longestKill': 4.079947,
#    'name': 'yourarirarira',
#    'playerId': 'account.27c9e109e949440983bca773d860b7a1',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 496,
#    'vehicleDestroys': 0,
#    'walkDistance': 360.19257,
#    'weaponsAcquired': 5,
#    'winPlace': 15}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 6,
#    'damageDealt': 94.095,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 4,
#    'killPlace': 30,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'haminjoond',
#    'playerId': 'account.fde2a521f4664ce3a6a384efb0489154',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 938,
#    'vehicleDestroys': 0,
#    'walkDistance': 1948.0437,
#    'weaponsAcquired': 3,
#    'winPlace': 2}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 2,
#    'damageDealt': 64.02389,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 40,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'KKo-gi',
#    'playerId': 'account.a2d66aec76b84be78565b48e013d5eec',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 463,
#    'vehicleDestroys': 0,
#    'walkDistance': 523.19684,
#    'weaponsAcquired': 5,
#    'winPlace': 16}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 1,
#    'damageDealt': 14.9926195,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 1,
#    'killPlace': 42,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'Anakalman',
#    'playerId': 'account.0895352590064df8bc78ed6dc24ca72a',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 430,
#    'vehicleDestroys': 0,
#    'walkDistance': 698.04156,
#    'weaponsAcquired': 4,
#    'winPlace': 18}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 1,
#    'damageDealt': 0,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 35,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'namelessk',
#    'playerId': 'account.893e4489063744aaab1b9f47c71b8815',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 494,
#    'vehicleDestroys': 0,
#    'walkDistance': 394.35703,
#    'weaponsAcquired': 5,
#    'winPlace': 11}},
#  {'shardId': 'steam', 'stats': {'rank': 33, 'teamId': 8}, 'won': 'false'},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 0,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 64,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'Ibis_06_07',
#    'playerId': 'account.b5dc639393b740168d78032e41d2d222',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 62,
#    'vehicleDestroys': 0,
#    'walkDistance': 21.488571,
#    'weaponsAcquired': 1,
#    'winPlace': 33}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 0,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 44,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'JimsS_ervices',
#    'playerId': 'ai.313',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 282,
#    'vehicleDestroys': 0,
#    'walkDistance': 0,
#    'weaponsAcquired': 0,
#    'winPlace': 19}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 1,
#    'assists': 0,
#    'boosts': 5,
#    'damageDealt': 680.6288,
#    'deathType': 'byplayer',
#    'headshotKills': 2,
#    'heals': 3,
#    'killPlace': 2,
#    'killStreaks': 2,
#    'kills': 6,
#    'longestKill': 191.92691,
#    'name': 'jjanggoo83',
#    'playerId': 'account.93b422d4179344cba40d6459cbf276c0',
#    'revives': 1,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 974,
#    'vehicleDestroys': 0,
#    'walkDistance': 1594.259,
#    'weaponsAcquired': 3,
#    'winPlace': 3}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 0,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 46,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'JYDQO',
#    'playerId': 'account.6d8b0fec56a14ef3b9703f295e4a65cb',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 297,
#    'vehicleDestroys': 0,
#    'walkDistance': 440.6331,
#    'weaponsAcquired': 4,
#    'winPlace': 21}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 1,
#    'assists': 0,
#    'boosts': 2,
#    'damageDealt': 345.78006,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 15,
#    'killPlace': 18,
#    'killStreaks': 1,
#    'kills': 1,
#    'longestKill': 234.25139,
#    'name': 'leedo96',
#    'playerId': 'account.480986b979624325b4e9b05e961da0f5',
#    'revives': 2,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 1,
#    'timeSurvived': 965,
#    'vehicleDestroys': 0,
#    'walkDistance': 1835.5962,
#    'weaponsAcquired': 9,
#    'winPlace': 5}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 0,
#    'assists': 0,
#    'boosts': 0,
#    'damageDealt': 0,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 51,
#    'killStreaks': 0,
#    'kills': 0,
#    'longestKill': 0,
#    'name': 'shinsunwoo',
#    'playerId': 'account.297b6c58cb254a9893aa842cdb910e67',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 221,
#    'vehicleDestroys': 0,
#    'walkDistance': 314.25464,
#    'weaponsAcquired': 1,
#    'winPlace': 24}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 1,
#    'assists': 0,
#    'boosts': 1,
#    'damageDealt': 122.68,
#    'deathType': 'byplayer',
#    'headshotKills': 1,
#    'heals': 1,
#    'killPlace': 23,
#    'killStreaks': 1,
#    'kills': 1,
#    'longestKill': 54.179497,
#    'name': 'GUNKICHI',
#    'playerId': 'account.3d3f0b63c0184cd89fc4cc2793595733',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 462,
#    'vehicleDestroys': 0,
#    'walkDistance': 583.1976,
#    'weaponsAcquired': 2,
#    'winPlace': 17}},
#  {'actor': '',
#   'shardId': 'steam',
#   'stats': {'DBNOs': 1,
#    'assists': 0,
#    'boosts': 3,
#    'damageDealt': 100,
#    'deathType': 'byplayer',
#    'headshotKills': 0,
#    'heals': 0,
#    'killPlace': 17,
#    'killStreaks': 1,
#    'kills': 1,
#    'longestKill': 87.22703,
#    'name': 'baaaaaaaaaamm',
#    'playerId': 'account.a1e75a4f0ac64b3eb4bcc6cdf20233d9',
#    'revives': 0,
#    'rideDistance': 0,
#    'roadKills': 0,
#    'swimDistance': 0,
#    'teamKills': 0,
#    'timeSurvived': 671,
#    'vehicleDestroys': 0,
#    'walkDistance': 906.3766,
#    'weaponsAcquired': 2,
#    'winPlace': 4}},
#  {'shardId': 'steam', 'stats': {'rank': 28, 'teamId': 18}, 'won': 'false'},
#  {'shardId': 'steam', 'stats': {'rank': 13, 'teamId': 6}, 'won': 'false'},
#  {'shardId': 'steam', 'stats': {'rank': 8, 'teamId': 25}, 'won': 'false'},
#  {'shardId': 'steam', 'stats': {'rank': 33, 'teamId': 17}, 'won': 'false'}]

# %%
for i in range(len(attribute_li)):
  if 'URL' in attribute_li[i]:
    tele = attribute_li[i]
    print(attribute_li.index(tele))
# Out:
# 73

# %%
tele
# Out:
# {'URL': 'https://telemetry-cdn.pubg.com/bluehole-pubg/steam/2021/09/03/15/37/cf835326-0ccc-11ec-bc41-6eb9a4f2a6c1-telemetry.json',
#  'createdAt': '2021-09-03T15:37:13Z',
#  'description': '',
#  'name': 'telemetry'}

# %%
attribute_li[73]  #tele랑 같은지 확인
# Out:
# {'URL': 'https://telemetry-cdn.pubg.com/bluehole-pubg/steam/2021/09/03/15/37/cf835326-0ccc-11ec-bc41-6eb9a4f2a6c1-telemetry.json',
#  'createdAt': '2021-09-03T15:37:13Z',
#  'description': '',
#  'name': 'telemetry'}

# %%
del attribute_li[73]

# %%
stats=[]

for i in range(len(attribute_li)):
    stats.append(attribute_li[i]['stats'])

# %%
columns=['name', 'playerId', 'DBNOs', 'assists', 'boosts', 'damageDealt', 'deathType',
         'headshotKills', 'heals', 'killPlace', 'killStreaks', 'kills', 'longestKill',
         'revives', 'rideDistance', 'roadKills', 'swimDistance', 'teamKills', 'timeSurvived',
         'vehicleDestroys', 'walkDistance', 'weaponsAcquired', 'winPlace']

stats_df = pd.DataFrame(stats, columns=columns)

# %%
stats_df
# Out:
#              name  ... winPlace
# 0           YECUD  ...     28.0
# 1       gkwns5919  ...     32.0
# 2         Berynie  ...      5.0
# 3    DEAD_ART1STS  ...     21.0
# 4     jaehomaster  ...      4.0
# ..            ...  ...      ...
# 91  baaaaaaaaaamm  ...      4.0
# 92            NaN  ...      NaN
# 93            NaN  ...      NaN
# 94            NaN  ...      NaN
# 95            NaN  ...      NaN
#
# [96 rows x 23 columns]

# %%
stats_df.isnull().sum()
# Out:
# name               33
# playerId           33
# DBNOs              33
# assists            33
# boosts             33
# damageDealt        33
# deathType          33
# headshotKills      33
# heals              33
# killPlace          33
# killStreaks        33
# kills              33
# longestKill        33
# revives            33
# rideDistance       33
# roadKills          33
# swimDistance       33
# teamKills          33
# timeSurvived       33
# vehicleDestroys    33
# walkDistance       33
# weaponsAcquired    33
# winPlace           33
# dtype: int64

# %%
stats_df.dropna()
# Out:
#              name  ... winPlace
# 0           YECUD  ...     28.0
# 1       gkwns5919  ...     32.0
# 2         Berynie  ...      5.0
# 3    DEAD_ART1STS  ...     21.0
# 4     jaehomaster  ...      4.0
# ..            ...  ...      ...
# 87          JYDQO  ...     21.0
# 88        leedo96  ...      5.0
# 89     shinsunwoo  ...     24.0
# 90       GUNKICHI  ...     17.0
# 91  baaaaaaaaaamm  ...      4.0
#
# [63 rows x 23 columns]

# %%
first_match_info['attributes']
match_info_df = pd.DataFrame(first_match_info['attributes'],index=[0])

# %%
match_info_df= match_info_df[['mapName', 'createdAt', 'duration', 'gameMode']]

# %%
match_info_df
# Out:
#            mapName             createdAt  duration gameMode
# 0  Summerland_Main  2021-09-03T15:15:38Z      1184      duo

# %%
tele_df = pd.DataFrame(data=tele, index=[0])
tele_df = tele_df[['URL']]

# %%
# 최종 match_info_df 정리()
match_info_df_result = pd.concat([match_info_df,tele_df], axis=1)
match_info_df_result #0번쨰 경기
# Out:
#            mapName  ...                                                URL
# 0  Summerland_Main  ...  https://telemetry-cdn.pubg.com/bluehole-pubg/s...
#
# [1 rows x 5 columns]

# %%
# 10경기 채택, first_match(첫경기) 제외
match = []
for i in range(1,len(matchId_li[:10])):
  match.append(requests.get(url+ matchId_li[i], headers=header).json())

# %%
len(match[0]['included']) #두번째 경기 참여자 97명
# Out:
# 97

# %%
match_data= []
match_info= []

for i in range(len(match)):
  match_data.append(match[i]['included']) #각 플레이어 관한 데이터가 'attributes'안에 있음(2~10경기 데이터)
  match_info.append(match[i]['data']) #해당게임 전반적인 데이터(2~10 경기 데이터)

# %%
match_data[0]  #두번째 경기 included 데이터
# Out:
# [{'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 50.760002,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 61,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'leedo96',
#     'playerId': 'account.480986b979624325b4e9b05e961da0f5',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 88,
#     'vehicleDestroys': 0,
#     'walkDistance': 7.4785028,
#     'weaponsAcquired': 1,
#     'winPlace': 30}},
#   'id': '1109bf42-f909-4496-a016-374d2da63b34',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 2,
#     'assists': 0,
#     'boosts': 8,
#     'damageDealt': 337,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 2,
#     'killPlace': 9,
#     'killStreaks': 1,
#     'kills': 2,
#     'longestKill': 34.12418,
#     'name': 'XXX_Bo1',
#     'playerId': 'account.cc156f7c0b834a91b5a7f3eb905856a5',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 951,
#     'vehicleDestroys': 0,
#     'walkDistance': 1431.9946,
#     'weaponsAcquired': 3,
#     'winPlace': 4}},
#   'id': 'fffdd5a0-084e-4da7-a509-1d42760f2d29',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 1,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 30.7,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 57,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'YECUD',
#     'playerId': 'account.8246582a51b841c69cd44a9d73ea4b5f',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 131,
#     'vehicleDestroys': 0,
#     'walkDistance': 239.2968,
#     'weaponsAcquired': 1,
#     'winPlace': 28}},
#   'id': '60ca4518-b55e-43ab-811b-fffe871be115',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 1,
#     'assists': 0,
#     'boosts': 5,
#     'damageDealt': 74.15744,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 3,
#     'killPlace': 18,
#     'killStreaks': 1,
#     'kills': 1,
#     'longestKill': 47.58649,
#     'name': 'Commander-Amari',
#     'playerId': 'account.a41ffa97e9544feb826d6ad83f6dddd5',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 737,
#     'vehicleDestroys': 0,
#     'walkDistance': 1285.3453,
#     'weaponsAcquired': 3,
#     'winPlace': 3}},
#   'id': 'd43b9ba7-1dad-4e29-ae45-051a5939471a',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 7,
#     'damageDealt': 37.2,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 36,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'Hagui_God',
#     'playerId': 'account.3673a4eb7b4447afbcd157eef6e3616c',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 843,
#     'vehicleDestroys': 0,
#     'walkDistance': 1281.1078,
#     'weaponsAcquired': 6,
#     'winPlace': 8}},
#   'id': '2d1c6740-0391-44dd-9ade-75af7e0437ba',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 3,
#     'damageDealt': 87.33566,
#     'deathType': 'byplayer',
#     'headshotKills': 1,
#     'heals': 5,
#     'killPlace': 21,
#     'killStreaks': 1,
#     'kills': 1,
#     'longestKill': 42.4213,
#     'name': 'kakakunu',
#     'playerId': 'account.835dcc8adfc6407699fc7b201c088e16',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 515,
#     'vehicleDestroys': 0,
#     'walkDistance': 958.45734,
#     'weaponsAcquired': 4,
#     'winPlace': 11}},
#   'id': 'd7abdc5b-176a-4d2f-8be0-33625996c157',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 1,
#     'assists': 1,
#     'boosts': 0,
#     'damageDealt': 196,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 1,
#     'killPlace': 14,
#     'killStreaks': 2,
#     'kills': 2,
#     'longestKill': 17.932795,
#     'name': 'raptor77',
#     'playerId': 'account.0831d1577c0a4fbd9c8d9565a43c3c25',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 254,
#     'vehicleDestroys': 0,
#     'walkDistance': 189.42601,
#     'weaponsAcquired': 2,
#     'winPlace': 20}},
#   'id': '2e64fd59-90bf-43fd-bfb6-a42be1a5e2e6',
#   'type': 'participant'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 14, 'teamId': 10},
#    'won': 'false'},
#   'id': 'dfd6398b-4127-47d8-9c3b-ef632e289623',
#   'relationships': {'participants': {'data': [{'id': 'f891230a-a3be-4ea8-8bb1-daf3f21ed613',
#       'type': 'participant'},
#      {'id': '550259ef-2cba-414d-a5d0-d6e2e51ef5c7', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 30, 'teamId': 11},
#    'won': 'false'},
#   'id': '098e9139-1b7d-49f2-9f80-b3201d750460',
#   'relationships': {'participants': {'data': [{'id': '1109bf42-f909-4496-a016-374d2da63b34',
#       'type': 'participant'},
#      {'id': 'b386f701-1731-466f-bf11-11eb2a8bba44', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 0,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 2,
#     'killPlace': 47,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'zzangsu715',
#     'playerId': 'account.a893d23575814c34b45ab8567e89f065',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 224,
#     'vehicleDestroys': 0,
#     'walkDistance': 261.03986,
#     'weaponsAcquired': 2,
#     'winPlace': 22}},
#   'id': '9a3e4c1b-e361-471a-9c26-4eabcf744073',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 1,
#     'assists': 0,
#     'boosts': 1,
#     'damageDealt': 163.67036,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 25,
#     'killStreaks': 1,
#     'kills': 1,
#     'longestKill': 3.4782138,
#     'name': 'seung0425',
#     'playerId': 'account.f2f283429ab54bda8158c0f85721381a',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 397,
#     'vehicleDestroys': 0,
#     'walkDistance': 876.39197,
#     'weaponsAcquired': 4,
#     'winPlace': 15}},
#   'id': 'fd3075f7-a55c-4696-b924-e604c63f91a6',
#   'type': 'participant'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 16, 'teamId': 29},
#    'won': 'false'},
#   'id': 'f3da1188-ebbf-4c68-a9b2-f1c7444d1307',
#   'relationships': {'participants': {'data': [{'id': '95a3dd87-35ee-4187-b491-97c68e15a517',
#       'type': 'participant'},
#      {'id': '115192c8-98c0-44e8-8c7f-6fd676f643ed', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 20, 'teamId': 4},
#    'won': 'false'},
#   'id': '5cfad140-13e8-4c41-9e44-af5e6f504af1',
#   'relationships': {'participants': {'data': [{'id': 'e4207b14-38fa-461d-ad4e-ef30e6f5b413',
#       'type': 'participant'},
#      {'id': '2e64fd59-90bf-43fd-bfb6-a42be1a5e2e6', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 1,
#     'assists': 1,
#     'boosts': 3,
#     'damageDealt': 373.345,
#     'deathType': 'byplayer',
#     'headshotKills': 1,
#     'heals': 1,
#     'killPlace': 4,
#     'killStreaks': 2,
#     'kills': 4,
#     'longestKill': 107.22962,
#     'name': 'Yaai_88',
#     'playerId': 'account.d5fe9ee04f29482aa50ceec77588f93b',
#     'revives': 1,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 920,
#     'vehicleDestroys': 0,
#     'walkDistance': 1433.7974,
#     'weaponsAcquired': 4,
#     'winPlace': 6}},
#   'id': '6c1d4c9a-b114-4391-b6d0-e0677add7efd',
#   'type': 'participant'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 15, 'teamId': 7},
#    'won': 'false'},
#   'id': '733fd866-52e5-496b-9319-28c298b57306',
#   'relationships': {'participants': {'data': [{'id': '90b9915b-f6a9-40ad-851d-c166d31fa235',
#       'type': 'participant'},
#      {'id': 'fd3075f7-a55c-4696-b924-e604c63f91a6', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 21, 'teamId': 8},
#    'won': 'false'},
#   'id': 'dd137847-1ac4-449d-9d41-fb7cee8ccbd2',
#   'relationships': {'participants': {'data': [{'id': '539c40fb-45ce-44e5-ad01-12e6869188bf',
#       'type': 'participant'},
#      {'id': 'd352ca01-44b1-41d0-aaff-04a61afa5176', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 25, 'teamId': 15},
#    'won': 'false'},
#   'id': 'ecc53adf-914a-419a-9121-20abb1dbe992',
#   'relationships': {'participants': {'data': [{'id': 'a11a4d04-9f15-4c7c-99f9-3d7f7dcb5b72',
#       'type': 'participant'},
#      {'id': '7a840d6b-221d-4ce8-922a-17b218ecefc7', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 0,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 49,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'Rudem1234',
#     'playerId': 'account.f68d3746fa2e473d916466c9f20a3940',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 199,
#     'vehicleDestroys': 0,
#     'walkDistance': 380.9877,
#     'weaponsAcquired': 3,
#     'winPlace': 23}},
#   'id': '5a6fc830-fdf3-4c64-b93b-28c1b7b2244e',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 63.14,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 53,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'buhungtek',
#     'playerId': 'account.2e4a47c86f2a49809d784680f82d2b3c',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 165,
#     'vehicleDestroys': 0,
#     'walkDistance': 211.29204,
#     'weaponsAcquired': 1,
#     'winPlace': 26}},
#   'id': '7688df86-6adc-48a6-ad10-40b40995fe52',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 1,
#     'assists': 1,
#     'boosts': 5,
#     'damageDealt': 64.25515,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 1,
#     'killPlace': 20,
#     'killStreaks': 1,
#     'kills': 1,
#     'longestKill': 28.576366,
#     'name': 'takurosekihara',
#     'playerId': 'account.e8afd462ce7148b683e8020c7924a10c',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 918,
#     'vehicleDestroys': 0,
#     'walkDistance': 1465.2489,
#     'weaponsAcquired': 8,
#     'winPlace': 6}},
#   'id': 'cdd20b19-6751-4ca8-93e2-7b170eaf8c0b',
#   'type': 'participant'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 22, 'teamId': 9},
#    'won': 'false'},
#   'id': 'd039e675-eeea-4d8a-941e-420baac56e8e',
#   'relationships': {'participants': {'data': [{'id': '3b7b5673-873f-4d5c-af2b-678e138bb16f',
#       'type': 'participant'},
#      {'id': '9a3e4c1b-e361-471a-9c26-4eabcf744073', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 17, 'teamId': 26},
#    'won': 'false'},
#   'id': 'c8a1357e-9d31-4ff4-aaa2-41a9e98d958e',
#   'relationships': {'participants': {'data': [{'id': 'ea52f435-92d4-4417-ba1e-cbc8ad32e78e',
#       'type': 'participant'},
#      {'id': 'ba8aced3-d393-447d-b439-4e39eee13c37', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 24, 'teamId': 23},
#    'won': 'false'},
#   'id': 'fa364e25-f83d-4f62-a42a-f6a74bab0a3d',
#   'relationships': {'participants': {'data': [{'id': '26167c60-9d22-417b-97c1-43ef482d3c0b',
#       'type': 'participant'},
#      {'id': 'bea37fe8-6663-485f-b91b-837ec03a5dd5', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 6,
#     'damageDealt': 99.41913,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 4,
#     'killPlace': 39,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'BBangYa07',
#     'playerId': 'account.83aa491fd27647b7adb4a2300711aa44',
#     'revives': 1,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 635,
#     'vehicleDestroys': 0,
#     'walkDistance': 1082.7091,
#     'weaponsAcquired': 3,
#     'winPlace': 10}},
#   'id': 'a20bcc7d-41cf-4405-aa53-87661f27fb71',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 1,
#     'damageDealt': 53.65,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 30,
#     'killStreaks': 1,
#     'kills': 1,
#     'longestKill': 53.42073,
#     'name': 'BIGHEADAZUMMA',
#     'playerId': 'account.f34e414c588d427c902b70e591f412c1',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 199,
#     'vehicleDestroys': 0,
#     'walkDistance': 344.49118,
#     'weaponsAcquired': 2,
#     'winPlace': 23}},
#   'id': '36b5d714-380c-4060-9437-50dab6714e3f',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 52.4205,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 5,
#     'killPlace': 51,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': '0ooYa',
#     'playerId': 'account.959247b26e3842de8d7b1fb1559dc5ec',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 179,
#     'vehicleDestroys': 0,
#     'walkDistance': 103.12713,
#     'weaponsAcquired': 1,
#     'winPlace': 24}},
#   'id': 'bea37fe8-6663-485f-b91b-837ec03a5dd5',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 0,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 1,
#     'killPlace': 44,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'jini_99',
#     'playerId': 'account.fa34c96238e34f13885c8dd4997db6d6',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 331,
#     'vehicleDestroys': 0,
#     'walkDistance': 419.46042,
#     'weaponsAcquired': 4,
#     'winPlace': 18}},
#   'id': '52676f08-a227-4960-9db2-3c66f302f280',
#   'type': 'participant'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 5, 'teamId': 22},
#    'won': 'false'},
#   'id': '87e93688-59db-4ac3-a103-354d1c6e3e9a',
#   'relationships': {'participants': {'data': [{'id': '85eaabbe-85c7-43e5-b0de-a9a75fc02c97',
#       'type': 'participant'},
#      {'id': 'c7d2f4eb-3d41-4ad7-9556-1f9a32931fba', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 31, 'teamId': 2},
#    'won': 'false'},
#   'id': '7c38eed5-dec7-42ea-9fb5-6948d5c36e14',
#   'relationships': {'participants': {'data': [{'id': 'ce930328-0ff5-492e-b6c1-70f39fdf0f3f',
#       'type': 'participant'},
#      {'id': '74e8b5de-28c4-4a93-8526-efb452ca5969', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 18, 'teamId': 3},
#    'won': 'false'},
#   'id': 'd41abff4-061b-4358-88d7-ed83bac25c1f',
#   'relationships': {'participants': {'data': [{'id': '5fb5456c-2690-431e-b44a-421f90a9b7bb',
#       'type': 'participant'},
#      {'id': '52676f08-a227-4960-9db2-3c66f302f280', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 1,
#     'damageDealt': 142.07878,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 1,
#     'killPlace': 41,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'Logitech0228',
#     'playerId': 'account.5b1e8f7032094a21946de86be4b7bb4d',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 412,
#     'vehicleDestroys': 0,
#     'walkDistance': 386.31042,
#     'weaponsAcquired': 3,
#     'winPlace': 14}},
#   'id': '550259ef-2cba-414d-a5d0-d6e2e51ef5c7',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 1,
#     'assists': 0,
#     'boosts': 2,
#     'damageDealt': 48.803158,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 1,
#     'killPlace': 23,
#     'killStreaks': 1,
#     'kills': 1,
#     'longestKill': 12.430017,
#     'name': 'FengYA_One',
#     'playerId': 'account.a087ed3f897c419c86e19430c3c62eb3',
#     'revives': 1,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 447,
#     'vehicleDestroys': 0,
#     'walkDistance': 415.73325,
#     'weaponsAcquired': 2,
#     'winPlace': 13}},
#   'id': '2d211495-2fe9-4e23-81f4-1e9c8e7e30ad',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 1,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 100,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 60,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'Berynie',
#     'playerId': 'account.840d28236c3b4bd2aba9b1e2baa92ef0',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 93,
#     'vehicleDestroys': 0,
#     'walkDistance': 62.67395,
#     'weaponsAcquired': 1,
#     'winPlace': 30}},
#   'id': 'b386f701-1731-466f-bf11-11eb2a8bba44',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 2,
#     'assists': 0,
#     'boosts': 5,
#     'damageDealt': 358.99994,
#     'deathType': 'byplayer',
#     'headshotKills': 1,
#     'heals': 3,
#     'killPlace': 3,
#     'killStreaks': 2,
#     'kills': 5,
#     'longestKill': 101.105194,
#     'name': 'andy4218',
#     'playerId': 'account.b3f75ccb09ff46e3b8640be360e21c33',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 806,
#     'vehicleDestroys': 0,
#     'walkDistance': 1436.0374,
#     'weaponsAcquired': 7,
#     'winPlace': 9}},
#   'id': '78b1d3b0-d476-4bd1-917d-2410c5991571',
#   'type': 'participant'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 23, 'teamId': 25},
#    'won': 'false'},
#   'id': '50ca1c86-4e42-4b29-98e8-35cbd63e829d',
#   'relationships': {'participants': {'data': [{'id': '36b5d714-380c-4060-9437-50dab6714e3f',
#       'type': 'participant'},
#      {'id': '5a6fc830-fdf3-4c64-b93b-28c1b7b2244e', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 12, 'teamId': 18},
#    'won': 'false'},
#   'id': '0c6a6897-1084-478e-8cde-69edd26d9ed5',
#   'relationships': {'participants': {'data': [{'id': 'ba832b41-6bb5-4065-ba1d-cb7c48b8921b',
#       'type': 'participant'},
#      {'id': '71f1ae41-7714-4627-99bb-4487c25a062e', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 1,
#     'assists': 1,
#     'boosts': 3,
#     'damageDealt': 349.19757,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 12,
#     'killStreaks': 2,
#     'kills': 2,
#     'longestKill': 28.094124,
#     'name': 'Panda_mz',
#     'playerId': 'account.639cc22fafe248779c0cf4cce4f25188',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 415,
#     'vehicleDestroys': 0,
#     'walkDistance': 450.72125,
#     'weaponsAcquired': 3,
#     'winPlace': 13}},
#   'id': '18804430-67c1-403d-8d63-4cdb146a2028',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 0,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 63,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'taehan_banggu',
#     'playerId': 'account.75a12499c7f44fc8811c45470ae66252',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 63,
#     'vehicleDestroys': 0,
#     'walkDistance': 7.7511406,
#     'weaponsAcquired': 1,
#     'winPlace': 32}},
#   'id': '7f54818f-63b5-4996-b87a-0bd5b99e07dd',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 0,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 46,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'seokgi5823',
#     'playerId': 'account.d1733f6461a747be9ae0cd3463b43f73',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 229,
#     'vehicleDestroys': 0,
#     'walkDistance': 394.30722,
#     'weaponsAcquired': 3,
#     'winPlace': 21}},
#   'id': 'd352ca01-44b1-41d0-aaff-04a61afa5176',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 1,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 116.859505,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 1,
#     'killPlace': 50,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'zzzary',
#     'playerId': 'account.e1ef05991202481c9f0431dbaff2fa20',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 179,
#     'vehicleDestroys': 0,
#     'walkDistance': 100.946045,
#     'weaponsAcquired': 1,
#     'winPlace': 24}},
#   'id': '26167c60-9d22-417b-97c1-43ef482d3c0b',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 1,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 302.81665,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 13,
#     'killStreaks': 1,
#     'kills': 2,
#     'longestKill': 85.85204,
#     'name': 'Garlic-Tangerine',
#     'playerId': 'account.3847ce08aea3475b96f2882ac51849e7',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 392,
#     'vehicleDestroys': 0,
#     'walkDistance': 359.91534,
#     'weaponsAcquired': 3,
#     'winPlace': 16}},
#   'id': '95a3dd87-35ee-4187-b491-97c68e15a517',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 1,
#     'assists': 0,
#     'boosts': 1,
#     'damageDealt': 125.19999,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 1,
#     'killPlace': 42,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'amns99',
#     'playerId': 'account.7bebceedfc9f41978959dc18ca834300',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 378,
#     'vehicleDestroys': 0,
#     'walkDistance': 536.1234,
#     'weaponsAcquired': 5,
#     'winPlace': 16}},
#   'id': '115192c8-98c0-44e8-8c7f-6fd676f643ed',
#   'type': 'participant'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 26, 'teamId': 5},
#    'won': 'false'},
#   'id': '9db2c672-89ef-4880-bf89-ee2ba7eba0e3',
#   'relationships': {'participants': {'data': [{'id': '7688df86-6adc-48a6-ad10-40b40995fe52',
#       'type': 'participant'},
#      {'id': '547ef3c0-c08b-4ac2-8f66-7bf8b8c340f1', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 32, 'teamId': 20},
#    'won': 'false'},
#   'id': '08f7fb65-24e0-4176-839d-f8ccb0e0e67e',
#   'relationships': {'participants': {'data': [{'id': '7b529929-af2e-4487-a495-f332cf56e6fc',
#       'type': 'participant'},
#      {'id': '7f54818f-63b5-4996-b87a-0bd5b99e07dd', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 85.33333,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 48,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'shin10-81',
#     'playerId': 'account.5bb5c2ceae104c43b590608c8c572bb1',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 224,
#     'vehicleDestroys': 0,
#     'walkDistance': 142.27412,
#     'weaponsAcquired': 1,
#     'winPlace': 22}},
#   'id': '3b7b5673-873f-4d5c-af2b-678e138bb16f',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 1,
#     'damageDealt': 49.14,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 34,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'Respection',
#     'playerId': 'account.c64d87abe4584f6992f9d81207f26761',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 910,
#     'vehicleDestroys': 0,
#     'walkDistance': 274.1272,
#     'weaponsAcquired': 3,
#     'winPlace': 7}},
#   'id': '4b8ba3bb-14df-4e45-94db-5230481b224b',
#   'type': 'participant'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 2, 'teamId': 13},
#    'won': 'false'},
#   'id': 'ad1f33b9-1ffc-459d-abe2-a508dcfdd731',
#   'relationships': {'participants': {'data': [{'id': '630b9e93-875f-406f-9d1c-57b6e940f079',
#       'type': 'participant'},
#      {'id': '3e592c12-537d-4251-a182-d396f4543705', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 0,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 52,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'zlzzlzz2l',
#     'playerId': 'account.9bf90d23595644fca6619dbf1d5b5f64',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 171,
#     'vehicleDestroys': 0,
#     'walkDistance': 111.96358,
#     'weaponsAcquired': 2,
#     'winPlace': 25}},
#   'id': 'a11a4d04-9f15-4c7c-99f9-3d7f7dcb5b72',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 2,
#     'damageDealt': 54.120003,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 2,
#     'killPlace': 37,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'he_ezzang',
#     'playerId': 'account.f85141b03c15461ea013629461b838e2',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 413,
#     'vehicleDestroys': 0,
#     'walkDistance': 386.96808,
#     'weaponsAcquired': 3,
#     'winPlace': 8}},
#   'id': '45eaf8b5-c5d0-4160-9d8c-77ed2c38c4dd',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 88,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 38,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'wdms12',
#     'playerId': 'account.164041778ca049649b257400cc6c90d9',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 84,
#     'vehicleDestroys': 0,
#     'walkDistance': 25.997671,
#     'weaponsAcquired': 1,
#     'winPlace': 9}},
#   'id': '205d2ed3-bde9-4765-9dd2-8cfe431210ac',
#   'type': 'participant'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 9, 'teamId': 19},
#    'won': 'false'},
#   'id': '69da6864-e26c-4801-93d6-b0b382e23c9e',
#   'relationships': {'participants': {'data': [{'id': '205d2ed3-bde9-4765-9dd2-8cfe431210ac',
#       'type': 'participant'},
#      {'id': '78b1d3b0-d476-4bd1-917d-2410c5991571', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 3,
#     'damageDealt': 124.734726,
#     'deathType': 'byplayer',
#     'headshotKills': 2,
#     'heals': 8,
#     'killPlace': 11,
#     'killStreaks': 2,
#     'kills': 2,
#     'longestKill': 85.60542,
#     'name': 'x2game625',
#     'playerId': 'account.c5a0c5f81c124a97aae42a9df11f48f2',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 614,
#     'vehicleDestroys': 0,
#     'walkDistance': 1026.1362,
#     'weaponsAcquired': 6,
#     'winPlace': 10}},
#   'id': 'd8bd0cc8-2dd8-4c8f-aa09-89dacfc9ba64',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 1,
#     'assists': 0,
#     'boosts': 1,
#     'damageDealt': 100,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 1,
#     'killPlace': 31,
#     'killStreaks': 1,
#     'kills': 1,
#     'longestKill': 2.5636818,
#     'name': 'rlaejrfuf1',
#     'playerId': 'account.c698b37eafff4f59aadcbaa8eed35ada',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 165,
#     'vehicleDestroys': 0,
#     'walkDistance': 143.18855,
#     'weaponsAcquired': 1,
#     'winPlace': 26}},
#   'id': '547ef3c0-c08b-4ac2-8f66-7bf8b8c340f1',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 0,
#     'deathType': 'byzone',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 40,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'cocadodo',
#     'playerId': 'account.6cd2bf5f9cc24491af2273fbcd4a1ef3',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 472,
#     'vehicleDestroys': 0,
#     'walkDistance': 872.1083,
#     'weaponsAcquired': 2,
#     'winPlace': 12}},
#   'id': '807be465-2add-4e14-8758-70adf7975827',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 1,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 115.81528,
#     'deathType': 'byplayer',
#     'headshotKills': 1,
#     'heals': 0,
#     'killPlace': 27,
#     'killStreaks': 1,
#     'kills': 1,
#     'longestKill': 153.47987,
#     'name': 'hyoski',
#     'playerId': 'account.5ff24869a9b34fce99f6e46cebed9f17',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 331,
#     'vehicleDestroys': 0,
#     'walkDistance': 478.37268,
#     'weaponsAcquired': 3,
#     'winPlace': 18}},
#   'id': '5fb5456c-2690-431e-b44a-421f90a9b7bb',
#   'type': 'participant'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 28, 'teamId': 1},
#    'won': 'false'},
#   'id': '7eca5d71-d472-469a-bf14-18af64b8c7e2',
#   'relationships': {'participants': {'data': [{'id': '60ca4518-b55e-43ab-811b-fffe871be115',
#       'type': 'participant'},
#      {'id': 'c8377f03-b534-4b8a-b491-913437398f71', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 0,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 58,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'TGP-666_9',
#     'playerId': 'ai.315',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 313,
#     'vehicleDestroys': 0,
#     'walkDistance': 357.78772,
#     'weaponsAcquired': 0,
#     'winPlace': 29}},
#   'id': '4287d4a1-71c2-4624-85aa-da3ce1d01b69',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 1,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 121.149994,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 26,
#     'killStreaks': 1,
#     'kills': 1,
#     'longestKill': 30.112282,
#     'name': 'Bono_B0no',
#     'playerId': 'account.910c2d727c4c4b3da7ccb29aa35324a3',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 119,
#     'vehicleDestroys': 0,
#     'walkDistance': 266.521,
#     'weaponsAcquired': 2,
#     'winPlace': 17}},
#   'id': 'ea52f435-92d4-4417-ba1e-cbc8ad32e78e',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 1,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 100,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 29,
#     'killStreaks': 1,
#     'kills': 1,
#     'longestKill': 1.8470085,
#     'name': 'Mobeleon',
#     'playerId': 'account.9e3cb9d2695c4b9aad70ef954939d2e9',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 229,
#     'vehicleDestroys': 0,
#     'walkDistance': 435.31485,
#     'weaponsAcquired': 3,
#     'winPlace': 21}},
#   'id': '539c40fb-45ce-44e5-ad01-12e6869188bf',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 1,
#     'boosts': 6,
#     'damageDealt': 158.92296,
#     'deathType': 'alive',
#     'headshotKills': 0,
#     'heals': 5,
#     'killPlace': 17,
#     'killStreaks': 1,
#     'kills': 1,
#     'longestKill': 51.84648,
#     'name': 'KjoonS2',
#     'playerId': 'account.ba7959ec90e4407caf79f66ee89af4ee',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 922,
#     'vehicleDestroys': 0,
#     'walkDistance': 2002.6106,
#     'weaponsAcquired': 10,
#     'winPlace': 1}},
#   'id': 'd1ce7aaa-2f07-444c-a0ad-6d23d5e6829b',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 0,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 64,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'yejin_banggu',
#     'playerId': 'account.2135da074d77473e86cf7f0c592b4b78',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 57,
#     'vehicleDestroys': 0,
#     'walkDistance': 10.330149,
#     'weaponsAcquired': 1,
#     'winPlace': 32}},
#   'id': '7b529929-af2e-4487-a495-f332cf56e6fc',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 1,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 100,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 32,
#     'killStreaks': 1,
#     'kills': 1,
#     'longestKill': 6.011184,
#     'name': 'OmyeonSalryuu',
#     'playerId': 'account.643c66963ee54335b0f9bbf251a5beeb',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 73,
#     'vehicleDestroys': 0,
#     'walkDistance': 18.246225,
#     'weaponsAcquired': 2,
#     'winPlace': 31}},
#   'id': 'ce930328-0ff5-492e-b6c1-70f39fdf0f3f',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 1,
#     'assists': 1,
#     'boosts': 7,
#     'damageDealt': 179.02167,
#     'deathType': 'byplayer',
#     'headshotKills': 1,
#     'heals': 3,
#     'killPlace': 5,
#     'killStreaks': 2,
#     'kills': 3,
#     'longestKill': 25.092363,
#     'name': 'rineunhyuk',
#     'playerId': 'account.6e6277c547924cff9d6e7019726c4e85',
#     'revives': 1,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 39.746357,
#     'teamKills': 0,
#     'timeSurvived': 1077,
#     'vehicleDestroys': 0,
#     'walkDistance': 2463.793,
#     'weaponsAcquired': 5,
#     'winPlace': 2}},
#   'id': '630b9e93-875f-406f-9d1c-57b6e940f079',
#   'type': 'participant'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 19, 'teamId': 24},
#    'won': 'false'},
#   'id': '9f2fe8bf-013c-4018-acea-839fd8b71dd2',
#   'relationships': {'participants': {'data': [{'id': '033fccb4-6a57-49dc-8c3f-a66c8d920750',
#       'type': 'participant'},
#      {'id': '0937dc76-3997-44bb-b107-a7a8d7c77a96', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 6, 'teamId': 31},
#    'won': 'false'},
#   'id': '25361d51-c560-4ca7-9e7c-6ddf7cd98241',
#   'relationships': {'participants': {'data': [{'id': '6c1d4c9a-b114-4391-b6d0-e0677add7efd',
#       'type': 'participant'},
#      {'id': 'cdd20b19-6751-4ca8-93e2-7b170eaf8c0b', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 5,
#     'damageDealt': 0,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 4,
#     'killPlace': 33,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'XXX_Razer',
#     'playerId': 'account.f39e0e1e5ebb4e229adcfceedd217fc2',
#     'revives': 1,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 951,
#     'vehicleDestroys': 0,
#     'walkDistance': 1388.7255,
#     'weaponsAcquired': 6,
#     'winPlace': 4}},
#   'id': 'd4145e71-f310-4a56-9239-89997b01cc25',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 1,
#     'assists': 0,
#     'boosts': 8,
#     'damageDealt': 334.37836,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 4,
#     'killPlace': 8,
#     'killStreaks': 1,
#     'kills': 2,
#     'longestKill': 52.613823,
#     'name': 'Alack-Horse',
#     'playerId': 'account.231cccd59a02477daa4a551bd294703f',
#     'revives': 1,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 1066,
#     'vehicleDestroys': 0,
#     'walkDistance': 1782.7297,
#     'weaponsAcquired': 6,
#     'winPlace': 3}},
#   'id': '957d7668-1e3a-46fd-b8f2-f9cc56a9aff0',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 0,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 62,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'Few-Few',
#     'playerId': 'account.2ba8889c2cc74a0da814eaba33c7d1f7',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 73,
#     'vehicleDestroys': 0,
#     'walkDistance': 16.122734,
#     'weaponsAcquired': 1,
#     'winPlace': 31}},
#   'id': '74e8b5de-28c4-4a93-8526-efb452ca5969',
#   'type': 'participant'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 7, 'teamId': 14},
#    'won': 'false'},
#   'id': '5fda96c9-a8ce-4a4e-b462-3ffb3c91b41b',
#   'relationships': {'participants': {'data': [{'id': '4b8ba3bb-14df-4e45-94db-5230481b224b',
#       'type': 'participant'},
#      {'id': 'cf74c86f-7111-49bb-b4dd-07929900e55e', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 4, 'teamId': 17},
#    'won': 'false'},
#   'id': 'd6b8840f-212a-4f38-9d43-c225f39a079e',
#   'relationships': {'participants': {'data': [{'id': 'd4145e71-f310-4a56-9239-89997b01cc25',
#       'type': 'participant'},
#      {'id': 'fffdd5a0-084e-4da7-a509-1d42760f2d29', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 1, 'teamId': 28},
#    'won': 'true'},
#   'id': '57026e5b-8a1e-41ad-a0b0-9e6adf8084bf',
#   'relationships': {'participants': {'data': [{'id': '3413e0c5-cebe-4fcf-b5ec-bf2c1df3acb8',
#       'type': 'participant'},
#      {'id': 'd1ce7aaa-2f07-444c-a0ad-6d23d5e6829b', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 13, 'teamId': 16},
#    'won': 'false'},
#   'id': 'dbda1e39-b127-44e4-b9e3-9dffb129b6fe',
#   'relationships': {'participants': {'data': [{'id': '2d211495-2fe9-4e23-81f4-1e9c8e7e30ad',
#       'type': 'participant'},
#      {'id': '18804430-67c1-403d-8d63-4cdb146a2028', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 11, 'teamId': 27},
#    'won': 'false'},
#   'id': 'b831eb73-b754-4e78-86f5-ade86fa82ab9',
#   'relationships': {'participants': {'data': [{'id': '807be465-2add-4e14-8758-70adf7975827',
#       'type': 'participant'},
#      {'id': 'd7abdc5b-176a-4d2f-8be0-33625996c157', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 1,
#     'assists': 0,
#     'boosts': 2,
#     'damageDealt': 123.66518,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 2,
#     'killPlace': 24,
#     'killStreaks': 1,
#     'kills': 1,
#     'longestKill': 5.1990814,
#     'name': 'zzara0620',
#     'playerId': 'account.5728621384b4451db91871f1acc9b1fb',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 397,
#     'vehicleDestroys': 0,
#     'walkDistance': 714.197,
#     'weaponsAcquired': 3,
#     'winPlace': 15}},
#   'id': '90b9915b-f6a9-40ad-851d-c166d31fa235',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 1,
#     'boosts': 0,
#     'damageDealt': 69.09,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 43,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'BCN-Orange',
#     'playerId': 'account.2108fc0f3b1742bd900bcaf0fa584b09',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 293,
#     'vehicleDestroys': 0,
#     'walkDistance': 392.2467,
#     'weaponsAcquired': 1,
#     'winPlace': 17}},
#   'id': 'ba8aced3-d393-447d-b439-4e39eee13c37',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 100,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 28,
#     'killStreaks': 1,
#     'kills': 1,
#     'longestKill': 3.1334352,
#     'name': 'Chul2ya',
#     'playerId': 'account.aa6735c8093c4951ab77bb2f7e02dd45',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 284,
#     'vehicleDestroys': 0,
#     'walkDistance': 357.72308,
#     'weaponsAcquired': 2,
#     'winPlace': 19}},
#   'id': '0937dc76-3997-44bb-b107-a7a8d7c77a96',
#   'type': 'participant'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 3, 'teamId': 21},
#    'won': 'false'},
#   'id': 'a47941a3-2f1a-438f-b4c0-b195fbdeffaf',
#   'relationships': {'participants': {'data': [{'id': '957d7668-1e3a-46fd-b8f2-f9cc56a9aff0',
#       'type': 'participant'},
#      {'id': 'd43b9ba7-1dad-4e29-ae45-051a5939471a', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 0,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 59,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'ifymbabb',
#     'playerId': 'ai.314',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 267,
#     'vehicleDestroys': 0,
#     'walkDistance': 29.405508,
#     'weaponsAcquired': 0,
#     'winPlace': 29}},
#   'id': '7d95b660-6382-48fc-8e46-0acd01fe56ee',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 69.3,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 56,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'HYUNseo236',
#     'playerId': 'account.ac195e4fbb8e41988741ba672b53dafd',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 131,
#     'vehicleDestroys': 0,
#     'walkDistance': 229.92758,
#     'weaponsAcquired': 1,
#     'winPlace': 28}},
#   'id': 'c8377f03-b534-4b8a-b491-913437398f71',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 1,
#     'boosts': 3,
#     'damageDealt': 150.37805,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 6,
#     'killPlace': 22,
#     'killStreaks': 1,
#     'kills': 1,
#     'longestKill': 7.179356,
#     'name': 'flowersknife',
#     'playerId': 'account.ffa8aaa45e4d46f099296e1752223bd5',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 509,
#     'vehicleDestroys': 0,
#     'walkDistance': 967.35834,
#     'weaponsAcquired': 6,
#     'winPlace': 12}},
#   'id': '71f1ae41-7714-4627-99bb-4487c25a062e',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 3,
#     'assists': 1,
#     'boosts': 9,
#     'damageDealt': 740.6227,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 5,
#     'killPlace': 2,
#     'killStreaks': 2,
#     'kills': 5,
#     'longestKill': 51.917526,
#     'name': 'Go_Around_',
#     'playerId': 'account.b7b0c324602c4e9988f5d6dc38c6931e',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 63.774925,
#     'teamKills': 0,
#     'timeSurvived': 1047,
#     'vehicleDestroys': 0,
#     'walkDistance': 2328.9358,
#     'weaponsAcquired': 4,
#     'winPlace': 2}},
#   'id': '3e592c12-537d-4251-a182-d396f4543705',
#   'type': 'participant'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 27, 'teamId': 30},
#    'won': 'false'},
#   'id': '216a4de5-b2be-4bd5-98be-fc8875abdcf5',
#   'relationships': {'participants': {'data': [{'id': '2f5866ff-473e-4d5f-a36f-b5cfaf9ec866',
#       'type': 'participant'},
#      {'id': 'eb1f46fd-6846-44cc-bd1a-8aaba3886eed', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 8, 'teamId': 6},
#    'won': 'false'},
#   'id': '7ff048c9-b286-4bc7-b22d-06fefe842dfb',
#   'relationships': {'participants': {'data': [{'id': '45eaf8b5-c5d0-4160-9d8c-77ed2c38c4dd',
#       'type': 'participant'},
#      {'id': '2d1c6740-0391-44dd-9ade-75af7e0437ba', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'URL': 'https://telemetry-cdn.pubg.com/bluehole-pubg/steam/2021/09/03/15/31/f2ea8045-0ccb-11ec-a7c2-2acd2b80c878-telemetry.json',
#    'createdAt': '2021-09-03T15:31:03Z',
#    'description': '',
#    'name': 'telemetry'},
#   'id': 'f2ea8045-0ccb-11ec-a7c2-2acd2b80c878',
#   'type': 'asset'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 2,
#     'assists': 0,
#     'boosts': 1,
#     'damageDealt': 530.1492,
#     'deathType': 'byplayer',
#     'headshotKills': 2,
#     'heals': 0,
#     'killPlace': 7,
#     'killStreaks': 2,
#     'kills': 3,
#     'longestKill': 39.675076,
#     'name': 'kimkijung8',
#     'playerId': 'account.970ba1d506154c52998aff93bd63ba84',
#     'revives': 1,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 418,
#     'vehicleDestroys': 0,
#     'walkDistance': 612.0916,
#     'weaponsAcquired': 2,
#     'winPlace': 14}},
#   'id': 'f891230a-a3be-4ea8-8bb1-daf3f21ed613',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 1,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 200,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 16,
#     'killStreaks': 2,
#     'kills': 2,
#     'longestKill': 14.036961,
#     'name': 'citizen135',
#     'playerId': 'account.dbef9dfb9609462f8a3f9da75c9ac4b5',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 97,
#     'vehicleDestroys': 0,
#     'walkDistance': 45.09223,
#     'weaponsAcquired': 3,
#     'winPlace': 25}},
#   'id': '7a840d6b-221d-4ce8-922a-17b218ecefc7',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 0,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 45,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'Daxxxxx',
#     'playerId': 'account.ad6fb708d4574fcdafcdd9072d926b2b',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 170,
#     'vehicleDestroys': 0,
#     'walkDistance': 188.28166,
#     'weaponsAcquired': 4,
#     'winPlace': 19}},
#   'id': '033fccb4-6a57-49dc-8c3f-a66c8d920750',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 3,
#     'assists': 1,
#     'boosts': 5,
#     'damageDealt': 772.3189,
#     'deathType': 'alive',
#     'headshotKills': 0,
#     'heals': 1,
#     'killPlace': 1,
#     'killStreaks': 2,
#     'kills': 5,
#     'longestKill': 106.40291,
#     'name': 'NormalPlayer',
#     'playerId': 'account.afe24b875fb046aeb6c312cf90cb8c2a',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 1080,
#     'vehicleDestroys': 0,
#     'walkDistance': 1648.0581,
#     'weaponsAcquired': 4,
#     'winPlace': 1}},
#   'id': '3413e0c5-cebe-4fcf-b5ec-bf2c1df3acb8',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 2,
#     'assists': 1,
#     'boosts': 3,
#     'damageDealt': 297.775,
#     'deathType': 'byplayer',
#     'headshotKills': 1,
#     'heals': 0,
#     'killPlace': 6,
#     'killStreaks': 2,
#     'kills': 3,
#     'longestKill': 48.043232,
#     'name': 'KimYChan',
#     'playerId': 'account.1388cd3fc8db4e9a969c77cad2e7bcff',
#     'revives': 1,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 417,
#     'vehicleDestroys': 0,
#     'walkDistance': 979.95013,
#     'weaponsAcquired': 3,
#     'winPlace': 12}},
#   'id': 'ba832b41-6bb5-4065-ba1d-cb7c48b8921b',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 2,
#     'assists': 1,
#     'boosts': 1,
#     'damageDealt': 669.5704,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 2,
#     'killPlace': 10,
#     'killStreaks': 1,
#     'kills': 2,
#     'longestKill': 7.825396,
#     'name': 'CDDE009',
#     'playerId': 'account.bad44989af504232bc132184dbcdb7f3',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 940,
#     'vehicleDestroys': 0,
#     'walkDistance': 1597.6694,
#     'weaponsAcquired': 5,
#     'winPlace': 5}},
#   'id': 'c7d2f4eb-3d41-4ad7-9556-1f9a32931fba',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 1,
#     'assists': 1,
#     'boosts': 0,
#     'damageDealt': 204,
#     'deathType': 'byplayer',
#     'headshotKills': 1,
#     'heals': 0,
#     'killPlace': 15,
#     'killStreaks': 1,
#     'kills': 2,
#     'longestKill': 3.5336764,
#     'name': 'euno33',
#     'playerId': 'account.1f972319bc7c4e6d978fda813c29ed60',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 221,
#     'vehicleDestroys': 0,
#     'walkDistance': 93.45517,
#     'weaponsAcquired': 3,
#     'winPlace': 20}},
#   'id': 'e4207b14-38fa-461d-ad4e-ef30e6f5b413',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 0,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 35,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'Storyghost',
#     'playerId': 'account.9efa5531b8f046f389bbcd6b3302bfe9',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 575,
#     'vehicleDestroys': 0,
#     'walkDistance': 850.33276,
#     'weaponsAcquired': 8,
#     'winPlace': 7}},
#   'id': 'cf74c86f-7111-49bb-b4dd-07929900e55e',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 0,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 55,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'Sherry_0504',
#     'playerId': 'account.6c0ac11d4b634c21bf447e68000a6ffd',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 134,
#     'vehicleDestroys': 0,
#     'walkDistance': 165,
#     'weaponsAcquired': 3,
#     'winPlace': 27}},
#   'id': '2f5866ff-473e-4d5f-a36f-b5cfaf9ec866',
#   'type': 'participant'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 29, 'teamId': 200},
#    'won': 'false'},
#   'id': '26c2ca3a-03f8-406e-8ec8-578fad338fd6',
#   'relationships': {'participants': {'data': [{'id': '4287d4a1-71c2-4624-85aa-da3ce1d01b69',
#       'type': 'participant'},
#      {'id': '7d95b660-6382-48fc-8e46-0acd01fe56ee', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'shardId': 'steam',
#    'stats': {'rank': 10, 'teamId': 12},
#    'won': 'false'},
#   'id': '3d91b121-f289-48af-a9e6-eb9a57c0dfda',
#   'relationships': {'participants': {'data': [{'id': 'a20bcc7d-41cf-4405-aa53-87661f27fb71',
#       'type': 'participant'},
#      {'id': 'd8bd0cc8-2dd8-4c8f-aa09-89dacfc9ba64', 'type': 'participant'}]},
#    'team': {'data': None}},
#   'type': 'roster'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 0,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 39.6,
#     'deathType': 'byplayer',
#     'headshotKills': 0,
#     'heals': 0,
#     'killPlace': 54,
#     'killStreaks': 0,
#     'kills': 0,
#     'longestKill': 0,
#     'name': 'segyunman_1003',
#     'playerId': 'account.73de4cec07a04db1a5c82a094b892cd0',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 161,
#     'vehicleDestroys': 0,
#     'walkDistance': 187.1282,
#     'weaponsAcquired': 2,
#     'winPlace': 27}},
#   'id': 'eb1f46fd-6846-44cc-bd1a-8aaba3886eed',
#   'type': 'participant'},
#  {'attributes': {'actor': '',
#    'shardId': 'steam',
#    'stats': {'DBNOs': 1,
#     'assists': 0,
#     'boosts': 0,
#     'damageDealt': 100,
#     'deathType': 'byplayer',
#     'headshotKills': 1,
#     'heals': 0,
#     'killPlace': 19,
#     'killStreaks': 1,
#     'kills': 1,
#     'longestKill': 2.299278,
#     'name': 'PinkWeasel',
#     'playerId': 'account.6d4811ac661d4515b822e92c7c753744',
#     'revives': 0,
#     'rideDistance': 0,
#     'roadKills': 0,
#     'swimDistance': 0,
#     'teamKills': 0,
#     'timeSurvived': 71,
#     'vehicleDestroys': 0,
#     'walkDistance': 21.33247,
#     'weaponsAcquired': 1,
#     'winPlace': 5}},
#   'id': '85eaabbe-85c7-43e5-b0de-a9a75fc02c97',
#   'type': 'participant'}]

# %%
len(match_data)  #match_data = [ []*9 ] 형태
# Out:
# 9

# %%
#TELEMETRY 정보 제외

for i in range(0, len(match_data[0])):
  if 'URL' in match_data[0][i]['attributes']:
    tele_1 = match_data[0][i]['attributes']
    del_tele_1 = match_data[0][i]
    print(match_data[0].index(del_tele_1))
    print(tele_1)
# Out:
# 83
# {'name': 'telemetry', 'description': '', 'createdAt': '2021-09-03T15:31:03Z', 'URL': 'https://telemetry-cdn.pubg.com/bluehole-pubg/steam/2021/09/03/15/31/f2ea8045-0ccb-11ec-a7c2-2acd2b80c878-telemetry.json'}

# %%
tele_1
# Out:
# {'URL': 'https://telemetry-cdn.pubg.com/bluehole-pubg/steam/2021/09/03/15/31/f2ea8045-0ccb-11ec-a7c2-2acd2b80c878-telemetry.json',
#  'createdAt': '2021-09-03T15:31:03Z',
#  'description': '',
#  'name': 'telemetry'}

# %%
del match_data[0][83]  #두번째 경기 TELE 빼내기

# %%
for i in range(0,len(match_data[1])):
  if 'URL' in match_data[1][i]['attributes']:
    tele_2 = match_data[1][i]['attributes']
    del_tele_2 = match_data[1][i]
    print(match_data[1].index(del_tele_2))

for i in range(0,len(match_data[2])):
  if 'URL' in match_data[2][i]['attributes']:
    tele_3 = match_data[2][i]['attributes']
    del_tele_3 = match_data[2][i]
    print(match_data[2].index(del_tele_3))

for i in range(0,len(match_data[3])):
  if 'URL' in match_data[3][i]['attributes']:
    tele_4 = match_data[3][i]['attributes']
    del_tele_4 = match_data[3][i]
    print(match_data[3].index(del_tele_4))

for i in range(0,len(match_data[4])):
  if 'URL' in match_data[4][i]['attributes']:
    tele_5 = match_data[4][i]['attributes']
    del_tele_5 = match_data[4][i]
    print(match_data[4].index(del_tele_5))

for i in range(0,len(match_data[5])):
  if 'URL' in match_data[5][i]['attributes']:
    tele_6 = match_data[5][i]['attributes']
    del_tele_6 = match_data[5][i]
    print(match_data[5].index(del_tele_6))


for i in range(0,len(match_data[6])):
  if 'URL' in match_data[6][i]['attributes']:
    tele_7 = match_data[6][i]['attributes']
    del_tele_7 = match_data[6][i]
    print(match_data[6].index(del_tele_7))

for i in range(0,len(match_data[7])):
  if 'URL' in match_data[7][i]['attributes']:
    tele_8 = match_data[7][i]['attributes']
    del_tele_8 = match_data[7][i]
    print(match_data[7].index(del_tele_8))

for i in range(0,len(match_data[8])):
  if 'URL' in match_data[8][i]['attributes']:
    tele_9 = match_data[8][i]['attributes']
    del_tele_9 = match_data[8][i]
    print(match_data[8].index(del_tele_9))
# Out:
# 35
# 80
# 13
# 123
# 71
# 72
# 51
# 106

# %%
print(tele_2)
print(tele_3)
print(tele_4)
print(tele_5)
print(tele_6)
print(tele_7)
print(tele_8)
print(tele_9)
# Out:
# {'name': 'telemetry', 'description': '', 'createdAt': '2021-09-03T15:28:57Z', 'URL': 'https://telemetry-cdn.pubg.com/bluehole-pubg/steam/2021/09/03/15/28/a8171577-0ccb-11ec-a4f6-b6764a209b64-telemetry.json'}
# {'description': '', 'createdAt': '2021-09-03T15:24:02Z', 'URL': 'https://telemetry-cdn.pubg.com/bluehole-pubg/steam/2021/09/03/15/24/f7d246e2-0cca-11ec-9285-ceb17c59f993-telemetry.json', 'name': 'telemetry'}
# {'URL': 'https://telemetry-cdn.pubg.com/bluehole-pubg/steam/2021/09/03/15/18/25ad28dd-0cca-11ec-8cd1-3a7d12022412-telemetry.json', 'name': 'telemetry', 'description': '', 'createdAt': '2021-09-03T15:18:09Z'}
# {'description': '', 'createdAt': '2021-09-03T15:22:15Z', 'URL': 'https://telemetry-cdn.pubg.com/bluehole-pubg/steam/2021/09/03/15/22/b8522e5d-0cca-11ec-a82d-96d55ecf8a05-telemetry.json', 'name': 'telemetry'}
# {'URL': 'https://telemetry-cdn.pubg.com/bluehole-pubg/steam/2021/09/03/15/03/20361fdd-0cc8-11ec-b5fb-d6e8d977c0d6-telemetry.json', 'name': 'telemetry', 'description': '', 'createdAt': '2021-09-03T15:03:41Z'}
# {'createdAt': '2021-09-03T14:55:07Z', 'URL': 'https://telemetry-cdn.pubg.com/bluehole-pubg/steam/2021/09/03/14/55/edab48e5-0cc6-11ec-80d6-aa0b54bbe244-telemetry.json', 'name': 'telemetry', 'description': ''}
# {'name': 'telemetry', 'description': '', 'createdAt': '2021-09-03T14:50:02Z', 'URL': 'https://telemetry-cdn.pubg.com/bluehole-pubg/steam/2021/09/03/14/50/37f05c6c-0cc6-11ec-ad0b-066b141a5266-telemetry.json'}
# {'name': 'telemetry', 'description': '', 'createdAt': '2021-09-03T14:34:52Z', 'URL': 'https://telemetry-cdn.pubg.com/bluehole-pubg/steam/2021/09/03/14/34/19a58e14-0cc4-11ec-be08-febf48ce5498-telemetry.json'}

# %%
# 9경기다 url 행 지우기(2번째는 위에서 지웠음)
del match_data[1][35]
del match_data[2][80]
del match_data[3][13]
del match_data[4][123]
del match_data[5][71]
del match_data[6][72]
del match_data[7][51]
del match_data[8][106]

# %%
attributes_2 = []
attributes_3 = []
attributes_4 = []
attributes_5 = []
attributes_6 = []
attributes_7 = []
attributes_8 = []
attributes_9 = []
attributes_10 = []

stats_2 = []
stats_3 = []
stats_4 = []
stats_5 = []
stats_6 = []
stats_7 = []
stats_8 = []
stats_9 = []
stats_10 = []

for i in range(len(match_data[0])):
  attributes_2.append(match_data[0][i]['attributes'])
  stats_2.append(attributes_2[i]['stats'])

for i in range(len(match_data[1])):
  attributes_3.append(match_data[1][i]['attributes'])
  stats_3.append(attributes_3[i]['stats'])

for i in range(len(match_data[2])):
  attributes_4.append(match_data[2][i]['attributes'])
  stats_4.append(attributes_4[i]['stats'])

for i in range(len(match_data[3])):
  attributes_5.append(match_data[3][i]['attributes'])
  stats_5.append(attributes_5[i]['stats'])

for i in range(len(match_data[4])):
  attributes_6.append(match_data[4][i]['attributes'])
  stats_6.append(attributes_6[i]['stats'])

for i in range(len(match_data[5])):
  attributes_7.append(match_data[5][i]['attributes'])
  stats_7.append(attributes_7[i]['stats'])

for i in range(len(match_data[6])):
  attributes_8.append(match_data[6][i]['attributes'])
  stats_8.append(attributes_8[i]['stats'])

for i in range(len(match_data[7])):
  attributes_9.append(match_data[7][i]['attributes'])
  stats_9.append(attributes_9[i]['stats'])

for i in range(len(match_data[8])):
  attributes_10.append(match_data[8][i]['attributes'])
  stats_10.append(attributes_10[i]['stats'])

# %%
attributes_2[0]['stats']
# Out:
# {'DBNOs': 0,
#  'assists': 0,
#  'boosts': 0,
#  'damageDealt': 50.760002,
#  'deathType': 'byplayer',
#  'headshotKills': 0,
#  'heals': 0,
#  'killPlace': 61,
#  'killStreaks': 0,
#  'kills': 0,
#  'longestKill': 0,
#  'name': 'leedo96',
#  'playerId': 'account.480986b979624325b4e9b05e961da0f5',
#  'revives': 0,
#  'rideDistance': 0,
#  'roadKills': 0,
#  'swimDistance': 0,
#  'teamKills': 0,
#  'timeSurvived': 88,
#  'vehicleDestroys': 0,
#  'walkDistance': 7.4785028,
#  'weaponsAcquired': 1,
#  'winPlace': 30}

# %%
matchId_df = pd.DataFrame(data=matchId_li[:10], columns=['matchId'])
matchId_df
# Out:
#                                 matchId
# 0  3d88e9f0-b06d-471d-a69e-941aae5a38f7
# 1  824cbfe1-754a-41cc-bd0b-ef91df625f62
# 2  6000851a-8769-4ed5-8890-c1b710e25ee9
# 3  0aae7fd8-6b76-4cbf-82ba-1743a62ae73e
# 4  89c726a4-7cb4-495c-9351-8f1befe0d8ca
# 5  1055d4c3-25cd-484e-a0db-7c20f6295f4f
# 6  31cd63f4-b5a7-4659-aca9-1686feec6e50
# 7  91587e1b-da4a-4f1f-98fc-f72e330e8a96
# 8  3d8b0e99-2d97-46b1-8da1-8bf6b5fef5a3
# 9  c7dd13b7-2094-4ae6-a4b9-4eb2ff40e38b

# %%
#10개의 게임 데이터 추출 코드(stats만 사용하면 됌)

stats_2_df = pd.DataFrame(stats_2, columns=columns)
stats_3_df = pd.DataFrame(stats_3, columns=columns)
stats_4_df = pd.DataFrame(stats_4, columns=columns)
stats_5_df = pd.DataFrame(stats_5, columns=columns)
stats_6_df = pd.DataFrame(stats_6, columns=columns)
stats_7_df = pd.DataFrame(stats_7, columns=columns)
stats_8_df = pd.DataFrame(stats_8, columns=columns)
stats_9_df = pd.DataFrame(stats_9, columns=columns)
stats_10_df = pd.DataFrame(stats_10, columns=columns)

# %%
stats_2_df = stats_2_df.dropna()
stats_3_df = stats_3_df.dropna()
stats_4_df = stats_4_df.dropna()
stats_5_df = stats_5_df.dropna()
stats_6_df = stats_6_df.dropna()
stats_7_df = stats_7_df.dropna()
stats_8_df = stats_8_df.dropna()
stats_9_df= stats_9_df.dropna()
stats_10_df= stats_10_df.dropna()

# %%
all_match_info = []
for i in range(len(match_info)):
  all_match_info.append(match_info[i]['attributes'])

# %%
all_match_info_df = pd.DataFrame(data = all_match_info)

# %%
all_match_info_df = all_match_info_df[['createdAt', 'mapName', 'duration', 'gameMode']]

# %%
all_match_info_df
# Out:
#               createdAt          mapName  duration gameMode
# 0  2021-09-03T15:11:11Z  Summerland_Main      1080      duo
# 1  2021-09-03T15:07:21Z  Summerland_Main      1185      duo
# 2  2021-09-03T15:04:24Z  Summerland_Main      1066      duo
# 3  2021-09-03T14:59:18Z  Summerland_Main      1020      duo
# 4  2021-09-03T14:50:31Z       Tiger_Main      1792      duo
# 5  2021-09-03T14:31:47Z       Tiger_Main      1801      duo
# 6  2021-09-03T14:22:52Z       Tiger_Main      1821      duo
# 7  2021-09-03T14:17:18Z       Tiger_Main      1850      duo
# 8  2021-09-03T14:02:53Z       Tiger_Main      1805      duo

# %%
tele_1_df = pd.DataFrame(data=tele_1, index=[0])
tele_1_df = tele_df[['URL']]

# %%
tele_1_df
# Out:
#                                                  URL
# 0  https://telemetry-cdn.pubg.com/bluehole-pubg/s...

# %%
all_tele = [tele_1, tele_2, tele_3, tele_4, tele_5, tele_6, tele_7, tele_8, tele_9]

# %%
all_tele_df = pd.DataFrame(data=all_tele)

# %%
all_tele_df = all_tele_df[['URL']]
all_tele_df = pd.concat([tele_df,all_tele_df], ignore_index=True)

# %%
all_tele_df
# Out:
#                                                  URL
# 0  https://telemetry-cdn.pubg.com/bluehole-pubg/s...
# 1  https://telemetry-cdn.pubg.com/bluehole-pubg/s...
# 2  https://telemetry-cdn.pubg.com/bluehole-pubg/s...
# 3  https://telemetry-cdn.pubg.com/bluehole-pubg/s...
# 4  https://telemetry-cdn.pubg.com/bluehole-pubg/s...
# 5  https://telemetry-cdn.pubg.com/bluehole-pubg/s...
# 6  https://telemetry-cdn.pubg.com/bluehole-pubg/s...
# 7  https://telemetry-cdn.pubg.com/bluehole-pubg/s...
# 8  https://telemetry-cdn.pubg.com/bluehole-pubg/s...
# 9  https://telemetry-cdn.pubg.com/bluehole-pubg/s...

# %%
all_match_info_df = pd.concat([match_info_df, all_match_info_df],ignore_index=True)

# %%
all_match_info_df = pd.concat([matchId_df, all_match_info_df], axis=1)

# %%
all_match_info_df
# Out:
#                                 matchId          mapName  ... duration  gameMode
# 0  3d88e9f0-b06d-471d-a69e-941aae5a38f7  Summerland_Main  ...     1184       duo
# 1  824cbfe1-754a-41cc-bd0b-ef91df625f62  Summerland_Main  ...     1080       duo
# 2  6000851a-8769-4ed5-8890-c1b710e25ee9  Summerland_Main  ...     1185       duo
# 3  0aae7fd8-6b76-4cbf-82ba-1743a62ae73e  Summerland_Main  ...     1066       duo
# 4  89c726a4-7cb4-495c-9351-8f1befe0d8ca  Summerland_Main  ...     1020       duo
# 5  1055d4c3-25cd-484e-a0db-7c20f6295f4f       Tiger_Main  ...     1792       duo
# 6  31cd63f4-b5a7-4659-aca9-1686feec6e50       Tiger_Main  ...     1801       duo
# 7  91587e1b-da4a-4f1f-98fc-f72e330e8a96       Tiger_Main  ...     1821       duo
# 8  3d8b0e99-2d97-46b1-8da1-8bf6b5fef5a3       Tiger_Main  ...     1850       duo
# 9  c7dd13b7-2094-4ae6-a4b9-4eb2ff40e38b       Tiger_Main  ...     1805       duo
#
# [10 rows x 5 columns]

# %%
# 최종 all_match_info_df (URL이 포함된 형태)

all_match_info_df = pd.concat([all_match_info_df, all_tele_df], axis=1)
all_match_info_df
# Out:
#                                 matchId  ...                                                URL
# 0  3d88e9f0-b06d-471d-a69e-941aae5a38f7  ...  https://telemetry-cdn.pubg.com/bluehole-pubg/s...
# 1  824cbfe1-754a-41cc-bd0b-ef91df625f62  ...  https://telemetry-cdn.pubg.com/bluehole-pubg/s...
# 2  6000851a-8769-4ed5-8890-c1b710e25ee9  ...  https://telemetry-cdn.pubg.com/bluehole-pubg/s...
# 3  0aae7fd8-6b76-4cbf-82ba-1743a62ae73e  ...  https://telemetry-cdn.pubg.com/bluehole-pubg/s...
# 4  89c726a4-7cb4-495c-9351-8f1befe0d8ca  ...  https://telemetry-cdn.pubg.com/bluehole-pubg/s...
# 5  1055d4c3-25cd-484e-a0db-7c20f6295f4f  ...  https://telemetry-cdn.pubg.com/bluehole-pubg/s...
# 6  31cd63f4-b5a7-4659-aca9-1686feec6e50  ...  https://telemetry-cdn.pubg.com/bluehole-pubg/s...
# 7  91587e1b-da4a-4f1f-98fc-f72e330e8a96  ...  https://telemetry-cdn.pubg.com/bluehole-pubg/s...
# 8  3d8b0e99-2d97-46b1-8da1-8bf6b5fef5a3  ...  https://telemetry-cdn.pubg.com/bluehole-pubg/s...
# 9  c7dd13b7-2094-4ae6-a4b9-4eb2ff40e38b  ...  https://telemetry-cdn.pubg.com/bluehole-pubg/s...
#
# [10 rows x 6 columns]

# %%
all_match_info_df['URL'][0]
# Out:
# 'https://telemetry-cdn.pubg.com/bluehole-pubg/steam/2021/09/03/15/37/cf835326-0ccc-11ec-bc41-6eb9a4f2a6c1-telemetry.json'

# %%
# stats(게임 데이터) 데이터프레임에 matchId 추가하기
stats_df = stats_df.dropna()
stats_df.reset_index(drop=True, inplace=True)
stats_2_df.reset_index(drop=True, inplace=True)
stats_3_df.reset_index(drop=True, inplace=True)
stats_4_df.reset_index(drop=True, inplace=True)
stats_5_df.reset_index(drop=True, inplace=True)
stats_6_df.reset_index(drop=True, inplace=True)
stats_7_df.reset_index(drop=True, inplace=True)
stats_8_df.reset_index(drop=True, inplace=True)
stats_9_df.reset_index(drop=True, inplace=True)
stats_10_df.reset_index(drop=True, inplace=True)

# %%
# stats(게임 데이터) 데이터프레임에 matchId 추가하기
stats_df['matcId'] = matchId[0]['id']
stats_2_df['matcId'] = matchId[1]['id']
stats_3_df['matcId'] = matchId[2]['id']
stats_4_df['matcId'] = matchId[3]['id']
stats_5_df['matcId'] = matchId[4]['id']
stats_6_df['matcId'] = matchId[5]['id']
stats_7_df['matcId'] = matchId[6]['id']
stats_8_df['matcId'] = matchId[7]['id']
stats_9_df['matcId'] = matchId[8]['id']
stats_10_df['matcId'] = matchId[9]['id']

# %%
stats_10_df
# Out:
#               name  ...                                matcId
# 0          lindh_-  ...  c7dd13b7-2094-4ae6-a4b9-4eb2ff40e38b
# 1   Asan-KooSungRi  ...  c7dd13b7-2094-4ae6-a4b9-4eb2ff40e38b
# 2           Uerine  ...  c7dd13b7-2094-4ae6-a4b9-4eb2ff40e38b
# 3       HelloJeff4  ...  c7dd13b7-2094-4ae6-a4b9-4eb2ff40e38b
# 4         Heo-Wook  ...  c7dd13b7-2094-4ae6-a4b9-4eb2ff40e38b
# ..             ...  ...                                   ...
# 94  Rumble_johnson  ...  c7dd13b7-2094-4ae6-a4b9-4eb2ff40e38b
# 95       KR_Bryant  ...  c7dd13b7-2094-4ae6-a4b9-4eb2ff40e38b
# 96          hs3254  ...  c7dd13b7-2094-4ae6-a4b9-4eb2ff40e38b
# 97        mmmm0421  ...  c7dd13b7-2094-4ae6-a4b9-4eb2ff40e38b
# 98           ELI05  ...  c7dd13b7-2094-4ae6-a4b9-4eb2ff40e38b
#
# [99 rows x 24 columns]
